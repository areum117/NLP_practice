# %% [markdown]
# # 전처리 연습 (Tokenize, Cleansing & Normalization, Stemming & Lemmatization)
#
# 1. 데이터셋을 찾는다. (만들어진, 크롤링, ...)
# 2. 전처리

# %%
import pandas as pd

data = pd.read_table('./steam.txt')
data['document'].head()
# Out:
# 0                               노래가 너무 적음
# 1         돌겠네 진짜. 황숙아, 어크 공장 그만 돌려라. 죽는다.
# 2        막노동 체험판 막노동 하는사람인데 장비를 내가 사야돼 뭐지
# 3    차악!차악!!차악!!! 정말 이래서 왕국을 되찾을 수 있는거야??
# 4     시간 때우기에 좋음.. 도전과제는 50시간이면 다 깰 수 있어요
# Name: document, dtype: str

# %%
import re

# 한글만 남김
pattern1 = re.compile(r'[^가-힣\s]')
# 여러 개의 공백을 하나로 매핑
pattern2 = re.compile(r'\s+')

clean_list = []

for text in data['document']:
    text = pattern1.sub(' ', text)
    text = pattern2.sub(' ', text)
    clean_list.append(text)

data['document'] = clean_list
data.head()
# Out:
#    label                          document
# 0      0                         노래가 너무 적음
# 1      0      돌겠네 진짜 황숙아 어크 공장 그만 돌려라 죽는다
# 2      1  막노동 체험판 막노동 하는사람인데 장비를 내가 사야돼 뭐지
# 3      1   차악 차악 차악 정말 이래서 왕국을 되찾을 수 있는거야
# 4      1   시간 때우기에 좋음 도전과제는 시간이면 다 깰 수 있어요

# %%
pattern = re.compile(r'(\b\w+\b)( \1)+')

normal_list = []

for text in data['document']:
    text = pattern.sub(r'\1\1', text)
    normal_list.append(text)

data['document'] = normal_list
data.head(20)
# Out:
#     label                                           document
# 0       0                                          노래가 너무 적음
# 1       0                       돌겠네 진짜 황숙아 어크 공장 그만 돌려라 죽는다
# 2       1                   막노동 체험판 막노동 하는사람인데 장비를 내가 사야돼 뭐지
# 3       1                        차악차악 정말 이래서 왕국을 되찾을 수 있는거야
# 4       1                    시간 때우기에 좋음 도전과제는 시간이면 다 깰 수 있어요
# 5       1               역시 재미있네요 전작에서 할수 없었던 자유로운 덱 빌딩도 좋네요
# 6       1                                           재미있었습니다
# 7       1                                   은근 쉽지만 은근 어려운 게임
# 8       0  베 스다 이 개 끼들아 시작할 때 체스판 돌아가는거 분동안 번 봤더나 빡치네 진짜 ...
# 9       1                                  시간 분동안 스트레스 다 풀림
# 10      0                                  걍 겜임 계정을 못만들어 미친겜
# 11      0                                         관람객 호랑이 불가
# 12      1                             재미쩡 초반에 좀 힘들어여 도트라서 조아
# 13      1  포켓볼 도 몰랐는데 이걸로 배워 갑니다 심심할때 하면 좋아요 컴퓨터 상대하는거 제대...
# 14      1                                      트레이아크 사랑해요 핰핰
# 15      0                 좆망겜 하지마 무슨 처음에 키자마자 매칭이 왜 렙하고 매칭되냐
# 16      1  뭐랄까 다크소울하는느낌이에요 죽으면 돈 다날라가는 방식 렙업하면서 무한 반복인거같은...
# 17      1  원하는거 보실려면 홈페이지 가셔서 패치를 사셔야 합니다 패치가 만원이라 사실상 만원...
# 18      0  안해 썩을 까진 그냥 대충 슥슥해도 되더니 에서 판때기를 직접 사용하는데 판을 밟는...
# 19      0                                                 우웩

# %%
from konlpy.tag import Okt

okt = Okt()

token_list = []

for text in data['document']:
    tokens = okt.morphs(text, stem=True)
    token_list.append(tokens)
    

data['tokens'] = token_list
data.head(20)
# Out:
#     label                                           document  \
# 0       0                                          노래가 너무 적음
# 1       0                       돌겠네 진짜 황숙아 어크 공장 그만 돌려라 죽는다
# 2       1                   막노동 체험판 막노동 하는사람인데 장비를 내가 사야돼 뭐지
# 3       1                        차악차악 정말 이래서 왕국을 되찾을 수 있는거야
# 4       1                    시간 때우기에 좋음 도전과제는 시간이면 다 깰 수 있어요
# 5       1               역시 재미있네요 전작에서 할수 없었던 자유로운 덱 빌딩도 좋네요
# 6       1                                           재미있었습니다
# 7       1                                   은근 쉽지만 은근 어려운 게임
# 8       0  베 스다 이 개 끼들아 시작할 때 체스판 돌아가는거 분동안 번 봤더나 빡치네 진짜 ...
# 9       1                                  시간 분동안 스트레스 다 풀림
# 10      0                                  걍 겜임 계정을 못만들어 미친겜
# 11      0                                         관람객 호랑이 불가
# 12      1                             재미쩡 초반에 좀 힘들어여 도트라서 조아
# 13      1  포켓볼 도 몰랐는데 이걸로 배워 갑니다 심심할때 하면 좋아요 컴퓨터 상대하는거 제대...
# 14      1                                      트레이아크 사랑해요 핰핰
# 15      0                 좆망겜 하지마 무슨 처음에 키자마자 매칭이 왜 렙하고 매칭되냐
# 16      1  뭐랄까 다크소울하는느낌이에요 죽으면 돈 다날라가는 방식 렙업하면서 무한 반복인거같은...
# 17      1  원하는거 보실려면 홈페이지 가셔서 패치를 사셔야 합니다 패치가 만원이라 사실상 만원...
# 18      0  안해 썩을 까진 그냥 대충 슥슥해도 되더니 에서 판때기를 직접 사용하는데 판을 밟는...
# 19      0                                                 우웩
#
#                                                tokens
# 0                                     [노래, 가, 너무, 적다]
# 1                [돌다, 진짜, 황숙, 아, 어크, 공장, 그만, 돌리다, 죽다]
# 2   [막노동, 체험판, 막노동, 하다, 사람, 인데, 장비, 를, 내, 가, 사다, 돼...
# 3                  [차악차악, 정말, 이래서, 왕국, 을, 되찾다, 수, 있다]
# 4      [시간, 때우다, 좋다, 도전, 과제, 는, 시간, 이면, 다, 깨다, 수, 있다]
# 5      [역시, 재미있다, 전작, 에서, 하다, 없다, 자유롭다, 덱, 빌딩, 도, 좋다]
# 6                                              [재미있다]
# 7                               [은근, 쉬다, 은근, 어렵다, 게임]
# 8   [베, 스, 다, 이, 개, 끼, 들, 아, 시작, 하다, 때, 체스판, 돌아가다,...
# 9                            [시간, 분동, 안, 스트레스, 다, 풀림]
# 10                     [걍, 겜임, 계정, 을, 못, 만들다, 미치다, 겜]
# 11                                     [관람객, 호랑이, 불가]
# 12                 [재미, 쩡, 초반, 에, 좀, 힘들다, 도트, 라서, 조아]
# 13  [포켓볼, 도, 모르다, 이, 걸, 로, 배우다, 가다, 심심하다, 때, 하다, 좋...
# 14                                [트레이아크, 사랑, 하다, 핰핰]
# 15  [좆망, 겜, 하다, 무슨, 처음, 에, 키, 자마자, 매칭, 이, 왜, 렙, 하고...
# 16  [뭐라다, 다크, 소울, 하, 는, 느낌, 이에요, 죽다, 돈, 다날, 라가, 는,...
# 17  [원하다, 보다, 홈페이지, 갈다, 패치, 를, 사다, 하다, 패치, 가, 만원, ...
# 18  [안해, 썩을, 까진, 그냥, 대충, 슥, 슥, 해도, 되다, 에서, 판때, 기르다...
# 19                                               [우웩]

# %%
ko_stopwords = set("아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼	어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다	하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 ".split())

# %%
token_list
# Out:
# [['노래', '가', '너무', '적다'],
#  ['돌다', '진짜', '황숙', '아', '어크', '공장', '그만', '돌리다', '죽다'],
#  ['막노동',
#   '체험판',
#   '막노동',
#   '하다',
#   '사람',
#   '인데',
#   '장비',
#   '를',
#   '내',
#   '가',
#   '사다',
#   '돼다',
#   '뭐',
#   '지'],
#  ['차악차악', '정말', '이래서', '왕국', '을', '되찾다', '수', '있다'],
#  ['시간', '때우다', '좋다', '도전', '과제', '는', '시간', '이면', '다', '깨다', '수', '있다'],
#  ['역시', '재미있다', '전작', '에서', '하다', '없다', '자유롭다', '덱', '빌딩', '도', '좋다'],
#  ['재미있다'],
#  ['은근', '쉬다', '은근', '어렵다', '게임'],
#  ['베',
#   '스',
#   '다',
#   '이',
#   '개',
#   '끼',
#   '들',
#   '아',
#   '시작',
#   '하다',
#   '때',
#   '체스판',
#   '돌아가다',
#   '분동',
#   '안',
#   '번',
#   '보다',
#   '더',
#   '나',
#   '빡치다',
#   '진짜',
#   '무한',
#   '로딩',
#   '버그',
#   '안',
#   '치다',
#   '고치다',
#   '겜',
#   '하다',
#   '거',
#   '냐'],
#  ['시간', '분동', '안', '스트레스', '다', '풀림'],
#  ['걍', '겜임', '계정', '을', '못', '만들다', '미치다', '겜'],
#  ['관람객', '호랑이', '불가'],
#  ['재미', '쩡', '초반', '에', '좀', '힘들다', '도트', '라서', '조아'],
#  ['포켓볼',
#   '도',
#   '모르다',
#   '이',
#   '걸',
#   '로',
#   '배우다',
#   '가다',
#   '심심하다',
#   '때',
#   '하다',
#   '좋다',
#   '컴퓨터',
#   '상대',
#   '하다',
#   '제대로',
#   '이기다',
#   '보고',
#   '싶다',
#   '자다',
#   '안되다'],
#  ['트레이아크', '사랑', '하다', '핰핰'],
#  ['좆망',
#   '겜',
#   '하다',
#   '무슨',
#   '처음',
#   '에',
#   '키',
#   '자마자',
#   '매칭',
#   '이',
#   '왜',
#   '렙',
#   '하고',
#   '매칭',
#   '되다'],
#  ['뭐라다',
#   '다크',
#   '소울',
#   '하',
#   '는',
#   '느낌',
#   '이에요',
#   '죽다',
#   '돈',
#   '다날',
#   '라가',
#   '는',
#   '방식',
#   '렙업',
#   '하다',
#   '무한',
#   '반복',
#   '인거',
#   '같다',
#   '재미있다',
#   '클래스',
#   '도',
#   '은근',
#   '많다',
#   '같다',
#   '또',
#   '캐릭터',
#   '를',
#   '계속',
#   '추가',
#   '하다',
#   '예정',
#   '인가',
#   '같다',
#   '그리고',
#   '하다',
#   '요소',
#   '하고',
#   '매번',
#   '던전',
#   '도',
#   '바뀌다',
#   '재미있다',
#   '돈',
#   '이',
#   '아깝다',
#   '않다',
#   '생각',
#   '드',
#   '네',
#   '요'],
#  ['원하다',
#   '보다',
#   '홈페이지',
#   '갈다',
#   '패치',
#   '를',
#   '사다',
#   '하다',
#   '패치',
#   '가',
#   '만원',
#   '이라',
#   '사실',
#   '상',
#   '만원',
#   '주다',
#   '게임',
#   '을',
#   '살다',
#   '건데',
#   '좋다'],
#  ['안해',
#   '썩을',
#   '까진',
#   '그냥',
#   '대충',
#   '슥',
#   '슥',
#   '해도',
#   '되다',
#   '에서',
#   '판때',
#   '기르다',
#   '직접',
#   '사용',
#   '하다',
#   '판',
#   '을',
#   '밟다',
#   '순간',
#   '서다',
#   '땅',
#   '이',
#   '변하다',
#   '버리다',
#   '뭔가',
#   '억울하다',
#   '하다',
#   '싫어지다',
#   '그래도',
#   '일단',
#   '이',
#   '놈',
#   '을',
#   '못자다',
#   '왠지',
#   '못',
#   '깨다',
#   '안',
#   '하다',
#   '같다',
#   '깨다',
#   '접다'],
#  ['우웩'],
#  ['로지텍', '마우스', '가', '드디어', '일', '한', '게임', '매크로', '없다', '흑우', '없다', '제'],
#  ['디스플레이', '에', '다소', '버그', '가', '있다', '게임', '자체', '는', '훌륭하다'],
#  ['압도',
#   '적',
#   '긍정',
#   '적',
#   '이든',
#   '뭐',
#   '든',
#   '나',
#   '랑',
#   '안',
#   '맞다',
#   '노잼',
#   '이라',
#   '는걸',
#   '새삼',
#   '느끼다',
#   '해주다',
#   '게임'],
#  ['명중', '률', '면', '인간', '적', '으로', '맞다', '야하다', '아니다'],
#  ['난', '되게', '재밋게햇넹', '딱', '킬링', '타', '임용', '으로', '적당하다'],
#  ['쓰레기', '게임', '절때', '사다'],
#  ['재미있다', '게임', '이지만', '티어', '올리다', '너무', '오래', '걸리다'],
#  ['걍', '이', '겜', '하다', '어리다', '무료', '겜', '인', '하다'],
#  ['이', '게임', '의', '단점'],
#  ['처음',
#   '에는',
#   '그냥',
#   '그렇다',
#   '횡스',
#   '크롤',
#   '액션',
#   '게임',
#   '정도',
#   '이다',
#   '단계',
#   '가',
#   '넘어가다',
#   '개발자',
#   '의',
#   '재치',
#   '가',
#   '엿',
#   '보이',
#   '는',
#   '게임',
#   '이네',
#   '요',
#   '중국',
#   '도',
#   '게임',
#   '이',
#   '많이',
#   '발전',
#   '하다',
#   '느끼다',
#   '있다',
#   '게임',
#   '이다'],
#  ['아', '중독', '성', '있다', '한번', '하다', '멈추다', '힘드다'],
#  ['개', '슈레', '기', '게임'],
#  ['이', '게임', '은', '정말', '좋다', '게임'],
#  ['세',
#   '일',
#   '을',
#   '들다',
#   '몇',
#   '퍼센트',
#   '를',
#   '하다',
#   '사다',
#   '이',
#   '한마디',
#   '면',
#   '되다',
#   '하다',
#   '사면',
#   '그',
#   '순간',
#   '넌',
#   '호갱',
#   '이',
#   '된거',
#   '다',
#   '무료',
#   '로',
#   '뿌리다',
#   '받다',
#   '카드',
#   '만',
#   '받다',
#   '난',
#   '이',
#   '게',
#   '어떻다',
#   '팔리다',
#   '되다',
#   '그게',
#   '차다',
#   '궁금하다'],
#  ['무료', '겜', '이', '적당하다'],
#  ['컴퓨터',
#   '로',
#   '하다',
#   '말다',
#   '걍',
#   '플스',
#   '로',
#   '하다',
#   '혼자',
#   '이상하다',
#   '낑기다',
#   '말',
#   '도',
#   '안되다',
#   '버벅',
#   '거림',
#   '시작',
#   '한지',
#   '시간',
#   '만',
#   '지우다',
#   '버리다',
#   '내용',
#   '을',
#   '보다',
#   '조',
#   '작',
#   '감',
#   '이',
#   '쓰레기',
#   '인',
#   '패드',
#   '랑',
#   '키',
#   '보드',
#   '다해',
#   '보다',
#   '혼자',
#   '이상하다',
#   '낑기다'],
#  ['레이싱',
#   '을',
#   '즐기다',
#   '수',
#   '있다',
#   '다른',
#   '오브젝트',
#   '와',
#   '차량',
#   '을',
#   '파괴',
#   '하다',
#   '수',
#   '있다',
#   '드리프트',
#   '가',
#   '조금',
#   '힘들다',
#   '레이싱',
#   '이',
#   '질린다',
#   '트랙',
#   '이',
#   '너무',
#   '쉬다',
#   '마이',
#   '시티',
#   '를',
#   '통해',
#   '서',
#   '자신',
#   '의',
#   '트랙',
#   '을',
#   '만들다',
#   '수',
#   '있다'],
#  ['훌륭하다', '절', '대다', '마', '코', '해'],
#  ['이', '거', '어뜨', '게', '하다', '굳다', '함'],
#  ['계속',
#   '적',
#   '으로',
#   '멈추다',
#   '현상',
#   '발생',
#   '왠만하다',
#   '전작',
#   '도',
#   '재밌다',
#   '하다',
#   '하다',
#   '도저히',
#   '불가능하다',
#   '포기'],
#  ['밸브',
#   '가',
#   '만들다',
#   '게임',
#   '인가요',
#   '뭔가',
#   '하프라이프',
#   '같다',
#   '느낌',
#   '이',
#   '드',
#   '고',
#   '그래픽',
#   '이랑',
#   '상대',
#   '적',
#   '이',
#   '외계',
#   '생명체',
#   '이고',
#   '협동',
#   '게임',
#   '이라니',
#   '역시',
#   '같이',
#   '하다',
#   '재밌다',
#   '추천',
#   '하다',
#   '무료',
#   '겜',
#   '이니',
#   '더',
#   '좋다',
#   '네',
#   '여',
#   '게다가',
#   '질',
#   '양',
#   '하다',
#   '싸우다',
#   '게임'],
#  ['재미있다',
#   '좀비',
#   '모드',
#   '라거',
#   '나',
#   '하다',
#   '모드',
#   '도',
#   '지원',
#   '하지만',
#   '알다',
#   '사람',
#   '없이',
#   '혼자',
#   '하다',
#   '조금',
#   '모자라다',
#   '느낌'],
#  ['심각하다', '노잼', '이다'],
#  ['처음',
#   '부터',
#   '긑',
#   '까지',
#   '현질',
#   '만',
#   '유도',
#   '하다',
#   '게임',
#   '어느',
#   '시점',
#   '이',
#   '되다',
#   '절대로',
#   '이기다',
#   '없다',
#   '사람',
#   '들',
#   '하고만',
#   '팀',
#   '매',
#   '치가',
#   '되다',
#   '걍',
#   '하다',
#   '하다',
#   '게임',
#   '게다가',
#   '서버',
#   '도',
#   '엄청',
#   '느리다',
#   '돈',
#   '밖에',
#   '모르다',
#   '게'],
#  ['갓', '겜', '세', '일', '하다', '때', '꼭', '사다'],
#  ['베데스다', '오다', '돼지', '새끼', '법', '규'],
#  ['마테', '체', '로', '썰다', '다니다', '너무', '재밌다', '없다', '스트레스', '도', '풀리다', '기분'],
#  ['실제',
#   '카지노',
#   '에서',
#   '포커',
#   '를',
#   '하다',
#   '한',
#   '기분',
#   '이',
#   '들어서다',
#   '너무',
#   '좋다',
#   '정말',
#   '잘',
#   '만들다',
#   '같다'],
#  ['왜', '도트겜', '인데', '프레임', '이', '많이', '끊기다', '게임', '좀', '해보다'],
#  ['게임',
#   '자체',
#   '는',
#   '외국',
#   '섭',
#   '만',
#   '보다',
#   '때',
#   '는',
#   '좋다',
#   '좆목',
#   '잼민',
#   '이',
#   '들다',
#   '여왕벌',
#   '이',
#   '삼위일체',
#   '를',
#   '이루다',
#   '한국',
#   '섭',
#   '은',
#   '가지',
#   '않다',
#   '정신건강',
#   '에',
#   '이',
#   '로움',
#   '한국',
#   '섭',
#   '들어가다',
#   '절차',
#   '가',
#   '금융',
#   '보안',
#   '프로그램',
#   '설치',
#   '급',
#   '이다'],
#  ['쓸모없다', '공군'],
#  ['솔', '끄다', '무료', '라고', '하다', '퀄', '개쩜'],
#  ['서든어택',
#   '표절',
#   '함',
#   '서든어택',
#   '도',
#   '총',
#   '쏘다',
#   '움직',
#   '이고',
#   '한',
#   '방',
#   '에',
#   '죽다',
#   '이',
#   '겜',
#   '이',
#   '배낌',
#   '에혀',
#   '개',
#   '노잼',
#   '망겜',
#   '이',
#   '다',
#   '이렇다',
#   '븅쉬갬'],
#  ['허다', '난', '울다'],
#  ['퇴근',
#   '하고',
#   '게임',
#   '은',
#   '하다',
#   '싶다',
#   '빡겜할',
#   '기운',
#   '은',
#   '없다',
#   '축',
#   '늘어지다',
#   '쉬엄쉬엄',
#   '하다',
#   '게임',
#   '극',
#   '후반',
#   '부',
#   '까지',
#   '진행',
#   '하다',
#   '엔딩',
#   '이',
#   '얼마',
#   '안남다',
#   '참다',
#   '못',
#   '하고',
#   '찍',
#   '싸다',
#   '드래곤볼',
#   '좋아하다',
#   '머',
#   '하다',
#   '동안',
#   '나쁘다',
#   '않다',
#   '남',
#   '에게',
#   '추천',
#   '은',
#   '도저히',
#   '못',
#   '하다'],
#  ['레벨',
#   '하나',
#   '깨다',
#   '때',
#   '마다',
#   '해당',
#   '멜로디',
#   '를',
#   '다시',
#   '확인',
#   '시키다',
#   '게',
#   '신경',
#   '을',
#   '과',
#   '하다',
#   '자극',
#   '하다',
#   '그렇다고',
#   '딱하다',
#   '합주',
#   '가',
#   '자극',
#   '이',
#   '적다',
#   '건',
#   '아니다',
#   '것',
#   '같다',
#   '퍼즐',
#   '난이도',
#   '는',
#   '서서히',
#   '높아지다',
#   '갑자기',
#   '차원',
#   '수가',
#   '하나',
#   '늘다',
#   '버리다',
#   '전',
#   '못',
#   '하다'],
#  ['게임', '더럽다', '어렵다', '그래픽', '은', '좋다', '노잼'],
#  ['탈출',
#   '하다',
#   '열중',
#   '하고',
#   '외',
#   '에',
#   '아무',
#   '생각',
#   '안',
#   '들어서다',
#   '좋다',
#   '하다',
#   '애매하다'],
#  ['삭제', '하다', '다시', '생각나다', '하다', '되다'],
#  ['한', '패가', '없다', '싯팔'],
#  ['점점',
#   '내',
#   '가',
#   '가해자',
#   '이고',
#   '악마',
#   '가',
#   '피해자',
#   '같다',
#   '걍',
#   '떄리다',
#   '불다',
#   '이다',
#   '힣'],
#  ['카악', '퉤'],
#  ['싱글',
#   '미션',
#   '이',
#   '더',
#   '많다',
#   '하다',
#   '아쉬움',
#   '이',
#   '남다',
#   '홈월드',
#   '를',
#   '플레이',
#   '한',
#   '기억',
#   '이',
#   '없다',
#   '이',
#   '시리즈',
#   '를',
#   '구매',
#   '하다',
#   '이유',
#   '가',
#   '있다',
#   '올드팬',
#   '이',
#   '아니다',
#   '구매',
#   '를',
#   '하다',
#   '않다',
#   '게',
#   '더',
#   '나다',
#   '있다',
#   '이',
#   '게임',
#   '을',
#   '대체',
#   '하다',
#   '한',
#   '게임',
#   '들',
#   '이',
#   '많다'],
#  ['머리', '쓰다', '게임', '퍼즐게임', '좋아하다', '유저', '라면', '피다'],
#  ['쿠키',
#   '클리커',
#   '의',
#   '스팀',
#   '판',
#   '굳이',
#   '켜다',
#   '않다',
#   '돈',
#   '이',
#   '차곡차곡',
#   '쌓이다',
#   '웹게임',
#   '처럼',
#   '어쩌다',
#   '한번',
#   '씩',
#   '만',
#   '들어오다',
#   '업그레이드',
#   '해주다',
#   '뒤',
#   '나가다',
#   '충분하다',
#   '즐기다',
#   '있다',
#   '이다'],
#  ['들이다',
#   '하다',
#   '거',
#   '보고',
#   '받다',
#   '너무',
#   '스토리',
#   '가',
#   '짧다',
#   '너무',
#   '쉬다',
#   '더',
#   '어렵다',
#   '만들다',
#   '주거',
#   '나',
#   '스토리',
#   '를',
#   '늘리다',
#   '게임',
#   '산',
#   '게',
#   '아깝다',
#   '지다'],
#  ['열차', '루트', '같이', '묶다', '팔다', '좋다', '같다', '초보자', '들', '은', '진짜', '헤매다'],
#  ['뿡', '밑', '탙'],
#  ['구입',
#   '하고',
#   '몇',
#   '년',
#   '째',
#   '하다',
#   '모르다',
#   '안',
#   '하다',
#   '울트라',
#   '와이드',
#   '모니터',
#   '구입',
#   '후',
#   '에',
#   '테스트',
#   '삼다',
#   '해보다',
#   '눈',
#   '깔다',
#   '돌아가다',
#   '레이싱',
#   '은',
#   '역시',
#   '울트라',
#   '와이드',
#   '모니터',
#   '로',
#   '하다',
#   '근데',
#   '난',
#   '역시',
#   '나',
#   '실력',
#   '이',
#   '늘',
#   '지',
#   '않다'],
#  ['장',
#   '국산',
#   '게임',
#   '예쁘다',
#   '일러스트',
#   '단',
#   '빠져들다',
#   '것',
#   '만',
#   '같다',
#   '동시',
#   '에',
#   '몰입',
#   '이',
#   '이상하다',
#   '안',
#   '되다',
#   '스토리',
#   '부분',
#   '적',
#   '인',
#   '국어',
#   '책',
#   '읽다',
#   '수준',
#   '의',
#   '연기',
#   '를',
#   '하다',
#   '다수',
#   '의',
#   '캐릭터',
#   '기본',
#   '적',
#   '으로',
#   '재미',
#   '가',
#   '없다',
#   '혼자',
#   '만',
#   '커플',
#   '없다',
#   '영조'],
#  ['배경화면', '보다', '게임', '별로', '안', '하다', '되다'],
#  ['이',
#   '게임',
#   '은',
#   '개',
#   '를',
#   '보다',
#   '것',
#   '뿐',
#   '만',
#   '아니다',
#   '무려',
#   '개',
#   '를',
#   '쓰다듬다',
#   '수도',
#   '있다',
#   '제목',
#   '이',
#   '게임',
#   '을',
#   '반도',
#   '표현',
#   '못',
#   '하다',
#   '게임',
#   '이',
#   '죠'],
#  ['난이도',
#   '가',
#   '너무',
#   '너무',
#   '높다',
#   '스테이지',
#   '부터',
#   '절망',
#   '을',
#   '맛보다',
#   '되다',
#   '장르',
#   '가',
#   '슈팅',
#   '인',
#   '만큼',
#   '은',
#   '매우',
#   '좋다',
#   '창',
#   '모드',
#   '고정',
#   '이',
#   '안되다',
#   '아쉽다',
#   '알트',
#   '앤터',
#   '로',
#   '일일',
#   '히',
#   '설정',
#   '하다',
#   '함'],
#  ['두',
#   '명',
#   '이',
#   '서',
#   '멀티',
#   '하다',
#   '배아',
#   '파',
#   '뒤지다',
#   '뻔하다',
#   '웃음',
#   '으로',
#   '운동',
#   '한다는',
#   '얘기',
#   '를',
#   '실감',
#   '함',
#   '분동',
#   '안',
#   '미치다',
#   '거마',
#   '냥',
#   '웃다',
#   '배',
#   '가',
#   '찢어지다',
#   '같다',
#   '광대뼈',
#   '가',
#   '쪼개다',
#   '같다',
#   '그만두다',
#   '웃기',
#   '싫다',
#   '웃기다',
#   '끌다',
#   '임'],
#  ['내', '가', '이', '게임', '뜨다', '하다', '근데', '이', '아니다', '이다', '눈물', '이', '나다'],
#  ['언어',
#   '압박',
#   '이',
#   '심하다',
#   '게임',
#   '이다',
#   '생각',
#   '보다',
#   '어렵다',
#   '재미',
#   '는',
#   '그다지',
#   '못',
#   '느끼다',
#   '게임',
#   '이라고',
#   '생각',
#   '하다'],
#  ['훌륭하다',
#   '작품',
#   '이다',
#   '단점',
#   '은',
#   '스토리',
#   '가',
#   '너무',
#   '짧다',
#   '장점',
#   '은',
#   '역시',
#   '툼레이더',
#   '이다'],
#  ['재미', '는', '있다', '사람', '이', '너무', '없다'],
#  ['조', '작', '감', '이', '좋다', '못', '하다'],
#  ['어떻다',
#   '게임',
#   '을',
#   '원하다',
#   '이',
#   '게임',
#   '을',
#   '구매',
#   '하다',
#   '정말',
#   '자다',
#   '알다',
#   '같다',
#   '이건',
#   '어떤',
#   '식',
#   '으로',
#   '들다',
#   '그',
#   '보다',
#   '못',
#   '한',
#   '게임',
#   '일',
#   '겁니다',
#   '그냥',
#   '노잼',
#   '세',
#   '일',
#   '을',
#   '하다',
#   '구매',
#   '하다',
#   '않다',
#   '것',
#   '이',
#   '더',
#   '좋다',
#   '생각',
#   '하다'],
#  ['재미있다', '와우'],
#  ['첫',
#   '엔딩',
#   '노멀',
#   '보다',
#   '너무',
#   '재밌다',
#   '하다',
#   '플레이',
#   '타임',
#   '은',
#   '비록',
#   '짧다',
#   '확',
#   '빠지다',
#   '드',
#   '네',
#   '요'],
#  ['로켓',
#   '을',
#   '조종',
#   '하다',
#   '무사하다',
#   '착륙시키다',
#   '게임',
#   '이렇다',
#   '뵈다',
#   '어렵다',
#   '폭팔',
#   '하다',
#   '이펙트',
#   '가',
#   '의외로',
#   '멋있다',
#   '난',
#   '무료',
#   '행사',
#   '때',
#   '얻다'],
#  ['세상', '에서', '제일', '아깝다', '불다'],
#  ['시간', '이면', '평가', '하다', '돼다', '아니다', '더하다', '요'],
#  ['타', '격감', '은', '히오스', '보다', '더', '좋다'],
#  ['처음', '엔', '컨텐츠', '가', '없다', '알다', '하다', '하다', '수록', '하다', '많다', '게임'],
#  ['아니다',
#   '발',
#   '내다',
#   '좋다',
#   '없다',
#   '게임',
#   '은',
#   '하다',
#   '수',
#   '있다',
#   '발매',
#   '하다',
#   '되다',
#   '같다',
#   '진짜',
#   '가격',
#   '도',
#   '존나',
#   '게',
#   '비싸다',
#   '기능',
#   '은',
#   '창작',
#   '마당',
#   '보다도',
#   '못',
#   '하고',
#   '빙융',
#   '시',
#   '시',
#   '인색',
#   '긱들'],
#  ['삶다',
#   '서로',
#   '를',
#   '죽',
#   '이며',
#   '살아가다',
#   '자연',
#   '과',
#   '인간',
#   '의',
#   '잔혹하다',
#   '새롭다',
#   '관점',
#   '에서',
#   '바라보다',
#   '게임'],
#  ['던파', '충', '들', '은', '이', '게임', '을', '해', '라'],
#  ['가성', '비', '최고', '의', '게임', '이다', '친구', '들', '이랑', '즐기다', '좋다'],
#  ['임',
#   '게임',
#   '다운',
#   '받다',
#   '실행',
#   '안되다',
#   '다이렉트',
#   '문제',
#   '로',
#   '실행',
#   '이',
#   '안되다',
#   '다이렉트',
#   '도',
#   '재',
#   '설치',
#   '하고',
#   '최신',
#   '버젼',
#   '으로',
#   '해봤다',
#   '소용없다',
#   '게임',
#   '들어가다',
#   '팅기다'],
#  ['서버', '에', '사람', '이', '없다', '중국', '인들', '때매', '다', '접다'],
#  ['병맛', '으로', '하다', '게임', '가격', '에', '비다', '개꿀'],
#  ['멀티플레이', '만큼은', '배필', '급'],
#  ['예전',
#   '테마',
#   '병원',
#   '을',
#   '생각',
#   '하고',
#   '구입',
#   '하다',
#   '오다',
#   '잠깐',
#   '하다',
#   '하다',
#   '오후',
#   '시',
#   '에',
#   '시작',
#   '을',
#   '하다',
#   '새벽',
#   '을',
#   '넘기다',
#   '있다',
#   '허허',
#   '허다',
#   '추천',
#   '하다',
#   '문상',
#   '으로',
#   '충전',
#   '하다',
#   '사다'],
#  ['사이버',
#   '멀미',
#   '를',
#   '느끼다',
#   '싶다',
#   '추천',
#   '게임',
#   '여러가지',
#   '해봤다',
#   '이',
#   '게임',
#   '이',
#   '처음',
#   '이다'],
#  ['진짜',
#   '꿀잼',
#   '게임',
#   '이',
#   '거',
#   '하다',
#   '보다',
#   '시간',
#   '가다',
#   '모름',
#   '모드',
#   '까지',
#   '깔다',
#   '하다',
#   '더',
#   '꿀잼'],
#  ['찬란하다',
#   '빛나다',
#   '남자',
#   '의',
#   '상징',
#   '그',
#   '길다',
#   '짧다',
#   '여정',
#   '은',
#   '개뿔',
#   '이',
#   '그냥',
#   '바바리맨',
#   '의',
#   '안',
#   '잡히다',
#   '놀이',
#   '겜'],
#  ['재밌다',
#   '버그',
#   '도',
#   '없어지다',
#   '중세시대',
#   '좋아하다',
#   '한번',
#   '쯤',
#   '해보다',
#   '함',
#   '처음',
#   '에',
#   '나오다',
#   '때',
#   '버그',
#   '좀',
#   '제대로',
#   '고치다',
#   '나오다',
#   '좋다'],
#  ['지금', '해도', '꿀잼', '인데', '지금', '해도', '멀미', '남', '으아', '못', '하다', '썽'],
#  ['쩌',
#   '는',
#   '게임',
#   '이다',
#   '꼭',
#   '해보다',
#   '더',
#   '이상',
#   '의',
#   '자세하다',
#   '설명',
#   '은',
#   '생략',
#   '하다',
#   '왜',
#   '냐',
#   '고요',
#   '스포일러',
#   '거들다'],
#  ['부모님',
#   '을',
#   '보이다',
#   '드리다',
#   '아주',
#   '좋아하다',
#   '근데',
#   '어머니',
#   '는',
#   '고래',
#   '가',
#   '무섭다',
#   '중간',
#   '에',
#   '포기',
#   '하',
#   '심',
#   '크다',
#   '크다',
#   '물고기',
#   '는',
#   '건드리다',
#   '도망가다',
#   '말미잘',
#   '은',
#   '건드리다',
#   '숨다',
#   '버리다',
#   '접대',
#   '용',
#   '으로',
#   '좋다',
#   '환불',
#   '않다',
#   '계속',
#   '가지',
#   '고',
#   '있다',
#   '생각',
#   '이네',
#   '요'],
#  ['전작',
#   '이',
#   '개띵작이었',
#   '지만',
#   '이',
#   '게임',
#   '은',
#   '그냥',
#   '망하다',
#   '물론',
#   '후속작',
#   '도',
#   '망하다',
#   '사다',
#   '걍',
#   '차라리',
#   '복돌',
#   '로',
#   '해',
#   '라'],
#  ['내',
#   '가',
#   '원하다',
#   '노래',
#   '로',
#   '리듬게임',
#   '을',
#   '하다',
#   '이',
#   '걸',
#   '로',
#   '도',
#   '대',
#   '만족'],
#  ['꺼지다', '고', '인물', '쉑들'],
#  ['저', '는', '반값', '에', '구매', '하다'],
#  ['프레임',
#   '은',
#   '고정',
#   '으로',
#   '계속',
#   '나오다',
#   '게임',
#   '자체',
#   '문제',
#   '로',
#   '계속',
#   '조금씩',
#   '버벅',
#   '이고',
#   '끊기다',
#   '그래픽',
#   '도',
#   '구림'],
#  ['아니다',
#   '왜',
#   '키안',
#   '주다',
#   '난리',
#   '시발',
#   '게임',
#   '어떻',
#   '게',
#   '하',
#   '라고',
#   '먼저',
#   '구매',
#   '한',
#   '사람',
#   '호갱',
#   '댓',
#   '구연'],
#  ['장기', '에프', '가슴', '털'],
#  ['실행', '안되다', '늘다', '좃망겜'],
#  ['친구',
#   '들',
#   '이랑',
#   '같이',
#   '하다',
#   '재미있다',
#   '멀미',
#   '가',
#   '너무',
#   '심하다',
#   '오래',
#   '못',
#   '하다'],
#  ['얼엑', '으로', '내놓다', '개발', '중단', '먹튀'],
#  ['너무',
#   '허무하다',
#   '그리고',
#   '주인공',
#   '그',
#   '특유',
#   '의',
#   '인생',
#   '혼자',
#   '다',
#   '산',
#   '허세',
#   '말투',
#   '짜증나다'],
#  ['네',
#   '코파',
#   '라',
#   '엑스트라',
#   '게임',
#   '시간',
#   '분량',
#   '을',
#   '분',
#   '으로',
#   '축약',
#   '한',
#   '애니매이션',
#   '이다',
#   '비교',
#   '적',
#   '짧다',
#   '시간',
#   '이라',
#   '느긋하다',
#   '보다',
#   '수',
#   '있다',
#   '앤딩곡',
#   '이',
#   '좋다',
#   '메이플',
#   '도',
#   '좋다'],
#  ['나가다',
#   '디',
#   '지세',
#   '요',
#   '유저',
#   '좆',
#   '목질',
#   '꼬',
#   '라지',
#   '뉴비',
#   '배척',
#   '오지',
#   '는',
#   '겜'],
#  ['내', '인생', '최고', '의', '생일', '선물'],
#  ['엣지', '보다', '훨', '좋다'],
#  ['업데이트',
#   '전',
#   '에는',
#   '오버',
#   '쿡',
#   '보다',
#   '쉬다',
#   '가면',
#   '갈수록',
#   '난이도',
#   '에',
#   '변동',
#   '이',
#   '없다',
#   '많이',
#   '실망',
#   '을',
#   '하다',
#   '난이도',
#   '가',
#   '좀더',
#   '높다',
#   '나오다',
#   '좋다',
#   '생각',
#   '을',
#   '하다',
#   '점수',
#   '대가',
#   '하나',
#   '추가',
#   '되다',
#   '그래도',
#   '만족도',
#   '가',
#   '올라가다',
#   '근데',
#   '너무',
#   '점수',
#   '대가',
#   '에바',
#   '잖다'],
#  ['화면', '전환'],
#  ['전',
#   '쏘다',
#   '쏘다',
#   '하다',
#   '시간',
#   '정도',
#   '즐겁다',
#   '하다',
#   '이정',
#   '도',
#   '가격',
#   '만족하다',
#   '다만',
#   '나중',
#   '이',
#   '되다',
#   '변수',
#   '는',
#   '거의',
#   '없어지다',
#   '습격',
#   '해오다',
#   '부족',
#   '들',
#   '만',
#   '강제',
#   '로',
#   '강하다',
#   '하다',
#   '느낌',
#   '이',
#   '너무',
#   '강하다',
#   '그',
#   '때',
#   '부터',
#   '재미',
#   '가',
#   '확',
#   '떨어지다',
#   '뭔가',
#   '다른',
#   '방법',
#   '도',
#   '추가',
#   '하다',
#   '하다',
#   '것',
#   '같다'],
#  ['웰',
#   '메이드',
#   '플랫포머',
#   '게임',
#   '조작',
#   '감',
#   '브금',
#   '액션',
#   '맵',
#   '구성',
#   '스토리',
#   '개인',
#   '적',
#   '으로',
#   '전부',
#   '다',
#   '맘',
#   '에',
#   '들다',
#   '옛날',
#   '게임',
#   '닌자',
#   '가',
#   '이',
#   '덴',
#   '과',
#   '매우',
#   '비슷하다',
#   '상위호환',
#   '이라고',
#   '볼',
#   '수',
#   '있다',
#   '어리다',
#   '적',
#   '페미',
#   '컴',
#   '게임',
#   '의',
#   '향수',
#   '를',
#   '느끼다',
#   '싶다',
#   '사람',
#   '들',
#   '은',
#   '필',
#   '구해',
#   '야하다',
#   '게임'],
#  ['재밌다', '고', '인물', '많다', '접다'],
#  ['빠요', '엔', '너무', '많다'],
#  ['정말로', '재다', '친구', '하다', '더', '재다'],
#  ['울', '삼촌', '이', '빠지다', '겜', '근데', '난', '노잼'],
#  ['재밌다', '다른사람', '들', '하다', '멘탈', '나가다', '보다', '더', '꿀잼'],
#  ['상당하다', '지루하다', '오픈월드'],
#  ['게임',
#   '이',
#   '재밌다',
#   '범인',
#   '추론',
#   '하다',
#   '과정',
#   '이',
#   '너무',
#   '억지',
#   '임',
#   '증거',
#   '없이',
#   '그냥',
#   '추론',
#   '만으로',
#   '범인',
#   '잡다',
#   '너무',
#   '위험하다',
#   '않다'],
#  ['남자', '의', '로망'],
#  ['노잼',
#   '인데',
#   '팀',
#   '포의',
#   '코믹',
#   '스럽다',
#   '움',
#   '을',
#   '따르다',
#   '싶다',
#   '보다',
#   '팀',
#   '포의',
#   '코믹',
#   '함',
#   '은',
#   '캐릭터',
#   '의',
#   '익숙하다',
#   '크다',
#   '바탕',
#   '을',
#   '이루다',
#   '있다',
#   '흉측하다',
#   '잔인하다',
#   '뿐이다',
#   '캐릭터',
#   '와',
#   '연출',
#   '로는',
#   '절대',
#   '안',
#   '되다',
#   '듯'],
#  ['은', '이다', '변하다', '거', '없다', '다', '들다', '도망치다'],
#  ['재미없다',
#   '처음',
#   '에는',
#   '오',
#   '헬기',
#   '드론',
#   '탱크',
#   '드론',
#   '이렇다',
#   '조종',
#   '하다',
#   '나름',
#   '괜찼',
#   '나',
#   '싶다',
#   '하다',
#   '하다',
#   '수록',
#   '재미',
#   '가',
#   '없어지다',
#   '헬기',
#   '딱',
#   '번',
#   '등장',
#   '함',
#   '탱크',
#   '가다',
#   '반',
#   '이고',
#   '컴퓨터',
#   '아군',
#   '전혀',
#   '도움',
#   '안되다',
#   '이',
#   '걸',
#   '왜',
#   '하다',
#   '모르다',
#   '그냥',
#   '묶음',
#   '떨이',
#   '로',
#   '하다',
#   '사다',
#   '엉',
#   '아니다'],
#  ['아', '제작자', '가', '버리다', '게임'],
#  ['게임', '은', '꿀잼', '이지만', '사람', '이', '너무', '없다', '멀티', '하다', '매우', '힘드다'],
#  ['이',
#   '사양',
#   '에',
#   '이',
#   '가격',
#   '에',
#   '이렇다',
#   '게임',
#   '구',
#   '하다',
#   '어렵다',
#   '이건',
#   '꼭',
#   '사다'],
#  ['모든',
#   '도전',
#   '과제',
#   '완료',
#   '성공하다',
#   '킥스타터',
#   '중',
#   '하나',
#   '인',
#   '웨이스트랜드',
#   '클래식',
#   '한',
#   '서양',
#   '알피',
#   '지',
#   '장르',
#   '를',
#   '좋아하다',
#   '꼭',
#   '해보다',
#   '하다',
#   '물론',
#   '아쉽다',
#   '점도',
#   '있다'],
#  ['음',
#   '걍',
#   '공짜',
#   '라는',
#   '것',
#   '도',
#   '갓',
#   '겜',
#   '인데',
#   '재미',
#   '도',
#   '있슴',
#   '하지만',
#   '쫄보',
#   '는',
#   '하다',
#   '셈',
#   '존시나',
#   '무서움'],
#  ['이',
#   '게임',
#   '이',
#   '다른',
#   '게임',
#   '과',
#   '차별',
#   '화',
#   '를',
#   '두다',
#   '있다',
#   '그건',
#   '이',
#   '게임',
#   '에는',
#   '점프',
#   '가',
#   '없다',
#   '것',
#   '이다',
#   '생존',
#   '겜',
#   '인데'],
#  ['엉',
#   '성하다',
#   '컷씬',
#   '지루하다',
#   '전투',
#   '사이드',
#   '퀘스트',
#   '부족',
#   '다른',
#   '지역',
#   '을',
#   '퀘스트',
#   '에',
#   '따라서',
#   '갈수',
#   '있다',
#   '퀘스트',
#   '를',
#   '다',
#   '깨다',
#   '후',
#   '에는',
#   '가지',
#   '못',
#   '하다',
#   '지역',
#   '존재',
#   '컷씬',
#   '장면',
#   '에서',
#   '주인공',
#   '의',
#   '이유',
#   '없다',
#   '얼굴',
#   '검다',
#   '칠',
#   '등',
#   '차',
#   '플레이',
#   '하다',
#   '싶다',
#   '않다',
#   '게임',
#   '이다'],
#  ['어렵다', '재밌다'],
#  ['서든'],
#  ['게임',
#   '좆',
#   '같이',
#   '만',
#   '드',
#   '네',
#   '시발',
#   '멀티',
#   '좀',
#   '해보다',
#   '하다',
#   '때',
#   '마다',
#   '팅기다',
#   '개',
#   '같다',
#   '게임',
#   '이'],
#  ['이', '게', '끝'],
#  ['맨', '탈', '박살', '남'],
#  ['개다', '씹다', '노잼', '트레일러', '에', '낚임'],
#  ['진짜',
#   '액션',
#   '성',
#   '플',
#   '래',
#   '이타입',
#   '바뀌다',
#   '참고',
#   '해보다',
#   '해도',
#   '번역',
#   '떄매',
#   '진짜',
#   '하다',
#   '싫어지다'],
#  ['내',
#   '가',
#   '이',
#   '게임',
#   '을',
#   '왜',
#   '사다',
#   '지금',
#   '까지',
#   '산',
#   '게임',
#   '중',
#   '에',
#   '가장',
#   '최악',
#   '이다'],
#  ['하다',
#   '키',
#   '보드',
#   '로',
#   '두',
#   '명',
#   '이',
#   '서',
#   '하다',
#   '있다',
#   '사다',
#   '사다',
#   '뭐',
#   '원',
#   '이라서',
#   '사다'],
#  ['출시',
#   '되다',
#   '지다',
#   '년',
#   '이',
#   '지나다',
#   '지금',
#   '도',
#   '나',
#   '에게',
#   '있다',
#   '이',
#   '게임',
#   '을',
#   '넘어서다',
#   '멀티플레이어',
#   '늘다',
#   '없다'],
#  ['게임', '은', '정말', '재미있다', '좋다', '한글', '번역', '을', '하다', '제대로', '해주다'],
#  ['이',
#   '게임',
#   '을',
#   '하다',
#   '구매',
#   '를',
#   '결심',
#   '하다',
#   '돼다',
#   '고맙다',
#   '네',
#   '코파',
#   '라',
#   '이브'],
#  ['트럼프', '님', '이나', '수술', '해드리다'],
#  ['스텐리', '재밌다', '하다', '재밌다', '하다', '함'],
#  ['재밌다', '팬심', '으로', '한', '듯'],
#  ['오다', '내', '가', '해보다', '퍼즐', '게임', '중', '제일', '어렵다'],
#  ['를', '지', '원안', '하고', '랑', '만', '지', '원함', '화질', '극혐', '화면', '짤림'],
#  ['이', '거', '로그인', '이', '안되다', '이름', '짓다', '힘드다'],
#  ['오크',
#   '관리',
#   '하다',
#   '시스템',
#   '이',
#   '너무',
#   '지나치다',
#   '정도',
#   '로',
#   '분량',
#   '이',
#   '많다',
#   '개',
#   '지역',
#   '이상',
#   '점령',
#   '하다',
#   '직접',
#   '하다',
#   '오크',
#   '성애자',
#   '임'],
#  ['게임',
#   '을',
#   '실행',
#   '함',
#   '과',
#   '동시',
#   '에',
#   '렉',
#   '이',
#   '걸리다',
#   '그런데',
#   '웃기다',
#   '것',
#   '은',
#   '정작',
#   '보다',
#   '켐페인',
#   '에',
#   '들어가다',
#   '렉',
#   '이',
#   '걸리다',
#   '않다',
#   '메인',
#   '화면',
#   '에서',
#   '렉',
#   '이',
#   '걸리다',
#   '않다',
#   '해주다',
#   '게임',
#   '을',
#   '사고',
#   '나서다',
#   '정낙',
#   '게임',
#   '을',
#   '못',
#   '하고',
#   '있다'],
#  ['아니다', '이', '게', '안되다', '아니다', '이', '게', '되다'],
#  ['내',
#   '가',
#   '헤봤을때',
#   '는',
#   '현질',
#   '유저',
#   '들',
#   '이',
#   '뉴비',
#   '를',
#   '학살',
#   '하다',
#   '장면',
#   '을',
#   '보다',
#   '존나',
#   '미치다'],
#  ['무섭다', '재미', '가', '없다', '마지막', '엔', '짜증', '만', '가득'],
#  ['음',
#   '돈',
#   '벌리다',
#   '만들다',
#   '게임',
#   '이',
#   '아니다',
#   '정말',
#   '자다',
#   '만들다',
#   '하다',
#   '뭔가',
#   '아니다',
#   '싶다',
#   '그냥',
#   '자기',
#   '맘',
#   '에',
#   '들다',
#   '만들다',
#   '되다',
#   '뭐',
#   '까지',
#   '찍다',
#   '동안',
#   '재밋',
#   '게',
#   '자다',
#   '하다',
#   '나중',
#   '에',
#   '컨텐츠',
#   '더',
#   '추가',
#   '되다',
#   '그때',
#   '다시',
#   '보다'],
#  ['너무', '어렵다', '빼다', '다', '너무', '좋다', '게임', '만들다', '고생', '하', '셧읍니', '다'],
#  ['구림'],
#  ['서버',
#   '관리',
#   '가',
#   '너무',
#   '안되다',
#   '피',
#   '씨방',
#   '에서',
#   '접속',
#   '하다',
#   '렉',
#   '은',
#   '기본',
#   '이고',
#   '튕',
#   '기기',
#   '까지',
#   '하니',
#   '너무',
#   '힘드다'],
#  ['운수', '좋다', '날일', '때', '하다', '친구', '랑', '하다', '더', '재미있다', '친구', '가', '없다'],
#  ['현재', '시간', '가량', '플레이', '중', '이다', '네', '시간', '동안', '못', '자다'],
#  ['왜', '멀미', '나다'],
#  ['게임', '이', '뭐', '하다', '없다'],
#  ['진',
#   '엔딩',
#   '보다',
#   '하다',
#   '말',
#   '인데',
#   '프롬',
#   '시발',
#   '놈',
#   '들',
#   '아',
#   '이',
#   '게',
#   '게임',
#   '이냐'],
#  ['특이점', '누르다', '후회', '함'],
#  ['환불', '안', '해주다', '박현준'],
#  ['하다', '겜', '이', '없다', '때', '하다', '사다', '이다', '다른', '겜', '접다'],
#  ['사람',
#   '이',
#   '없다',
#   '혼자',
#   '하다',
#   '재미',
#   '없다',
#   '스토리',
#   '없다',
#   '그리고',
#   '삭제',
#   '이',
#   '걸',
#   '로',
#   '설명',
#   '끝'],
#  ['컨텐츠', '얼마', '없다', '하다', '없다'],
#  ['내', '로그라이크', '모드', '어디', '가다'],
#  ['한국어', '패치', '버전', '이', '없다', '가장', '아쉽다', '한글패치', '꼭좀', '나오다', '좋다'],
#  ['제발', '젠', '채다', '터좀', '줄다'],
#  ['낙지', '볶음', '시뮬레이터', '개꿀잼', '내', '인생', '게임'],
#  ['충성', '충성', '싸', '돌아다니다', '좋아하다', '갓', '겜'],
#  ['이런', '류', '의', '캐', '쥬얼', '게임', '좋아하다', '후속작', '은', '없다', '건가', '요'],
#  ['재밌다',
#   '한데',
#   '이',
#   '게임',
#   '의',
#   '가장',
#   '크다',
#   '문제',
#   '는',
#   '컨텐츠',
#   '가',
#   '너무',
#   '한정',
#   '적',
#   '이라는',
#   '점',
#   '이다',
#   '계속',
#   '똑같다',
#   '거만',
#   '하다',
#   '되다',
#   '금방',
#   '질리',
#   '게',
#   '되다',
#   '단점',
#   '이',
#   '있다',
#   '혹시',
#   '이',
#   '게임',
#   '을',
#   '사실',
#   '불다',
#   '이',
#   '게임',
#   '은',
#   '딱하다',
#   '안',
#   '하다',
#   '낫다',
#   '는',
#   '점',
#   '을',
#   '말씀드리다',
#   '싶다'],
#  ['재미', '는', '있다', '도전', '과제', '가', '사람', '을', '찝찝하다', '만드', '네'],
#  ['좀비',
#   '가',
#   '사칙연산',
#   '하다',
#   '게임',
#   '머리',
#   '가',
#   '좋아지다',
#   '느끼다',
#   '팁',
#   '기호',
#   '는',
#   '나누기',
#   '이다',
#   '은',
#   '이',
#   '거땜',
#   '에',
#   '난이도',
#   '가',
#   '급상승'],
#  ['권총', '쏘다', '재미', '하나', '는', '원', '탑', '이다', '이', '말', '이야'],
#  ['하다', '턴', '만', '더', '분만', '더', '하다', '시간', '만', '더', '하루', '만', '더'],
#  ['엔딩', '조건', '빼다', '전작', '이랑', '뭐', '가', '달리다'],
#  ['정말', '그래픽', '게임', '성', '뭐', '하나', '빠지다', '않다', '쓰레기', '게임', '이네', '요'],
#  ['오른쪽',
#   '팔이',
#   '펌핑',
#   '이',
#   '되어다',
#   '마우스',
#   '회사',
#   '에서',
#   '마우스',
#   '를',
#   '전부',
#   '파괴',
#   '하다',
#   '만들다',
#   '프로그램',
#   '인가',
#   '보다',
#   '원래',
#   '마우스',
#   '클릭',
#   '횟수',
#   '가',
#   '수명',
#   '아니다',
#   '아',
#   '팔',
#   '아프다',
#   '도전',
#   '과제',
#   '순식간',
#   '에',
#   '클리어',
#   '한',
#   '건',
#   '좋다'],
#  ['개', '좋다'],
#  ['바탕화면', '꾸미다', '아주', '좋다'],
#  ['아',
#   '진짜',
#   '컨베이어',
#   '벨트',
#   '깔다',
#   '각종',
#   '방향',
#   '버그',
#   '그리고',
#   '시스템',
#   '작동시키다',
#   '온갖',
#   '오류',
#   '가',
#   '넘치다',
#   '빡치다',
#   '접다'],
#  ['가다', '멍청하다', '싫다'],
#  ['차라리', '유로', '트럭', '를', '하다'],
#  ['프레임', '드랍', '너무', '심하다'],
#  ['다듬다', '하다', '너무', '많다', '타', '격감', '이나', '타다', '속', '버그', '등'],
#  ['퍼즐',
#   '은',
#   '좋다',
#   '너무',
#   '터',
#   '무니',
#   '없다',
#   '곳',
#   '에서',
#   '퍼즐',
#   '조각',
#   '들',
#   '이',
#   '나오다',
#   '그리고',
#   '막히다',
#   '싶다',
#   '무작정',
#   '더블클릭',
#   '을',
#   '해보다',
#   '확대',
#   '되다',
#   '예',
#   '상치',
#   '못',
#   '한',
#   '곳',
#   '이',
#   '있다',
#   '렌즈',
#   '를',
#   '무조건',
#   '써다',
#   '보다',
#   '야하다'],
#  ['무료',
#   '체험판',
#   '해봤다',
#   '게임',
#   '은',
#   '잘',
#   '만들다',
#   '못',
#   '사다',
#   '너무',
#   '잘',
#   '만들다',
#   '너무',
#   '무섭다'],
#  ['단점',
#   '강제',
#   '적',
#   '으로',
#   '보여주다',
#   '컷신',
#   '이',
#   '많다',
#   '플레이',
#   '분도',
#   '안되다',
#   '보이다',
#   '캐릭터',
#   '의',
#   '부자연스럽다',
#   '움직임',
#   '더럽다',
#   '조작',
#   '감',
#   '장점',
#   '이',
#   '모든',
#   '걸',
#   '분도',
#   '안되다',
#   '느끼다',
#   '수',
#   '있다',
#   '환불',
#   '결정',
#   '이',
#   '빠르다'],
#  ['오픈월드',
#   '에서',
#   '경찰',
#   '과',
#   '도둑',
#   '하다',
#   '굴잼',
#   '게임',
#   '인데',
#   '커스터',
#   '마',
#   '이징도',
#   '무궁무진',
#   '하고',
#   '좋다',
#   '게임',
#   '을',
#   '망치다',
#   '이유',
#   '운영',
#   '이',
#   '망치다',
#   '페이',
#   '투윈',
#   '고',
#   '인물',
#   '많다',
#   '개인',
#   '적',
#   '으로',
#   '이런',
#   '느낌',
#   '의',
#   '오픈월드',
#   '게임',
#   '이',
#   '또',
#   '나오다',
#   '좋다',
#   '읍니',
#   '다'],
#  ['고대',
#   '의',
#   '전투',
#   '를',
#   '재현',
#   '하다',
#   '본래',
#   '의',
#   '재미',
#   '는',
#   '여전하다',
#   '하지만',
#   '내정',
#   '이라고',
#   '하다',
#   '한',
#   '것',
#   '이',
#   '없다',
#   '반복',
#   '전투',
#   '에',
#   '지겹다',
#   '때',
#   '매력',
#   '이',
#   '다',
#   '하다',
#   '느낌',
#   '이다'],
#  ['아쉽다'],
#  ['이', '것', '이', '바로', '시간', '을', '거', '스르', '는', '자'],
#  ['어우',
#   '중국',
#   '발',
#   '미세먼지',
#   '가',
#   '게임',
#   '도',
#   '더럽히다',
#   '착',
#   '짱',
#   '죽',
#   '짱',
#   '은',
#   '진리',
#   '다'],
#  ['흠',
#   '현실',
#   '성',
#   '이',
#   '굉장하다',
#   '뛰어나다',
#   '흔',
#   '근',
#   '히',
#   '세력',
#   '에',
#   '대한',
#   '감정',
#   '싸움',
#   '은',
#   '물론',
#   '특히',
#   '일본',
#   '과',
#   '우리나라',
#   '의',
#   '감정',
#   '싸움',
#   '이',
#   '특히',
#   '매우',
#   '가하다',
#   '그래서',
#   '그런',
#   '걸',
#   '끄다',
#   '아니다',
#   '이',
#   '게임',
#   '이',
#   '완성',
#   '도',
#   '가',
#   '굉장하다',
#   '높다',
#   '그렇다',
#   '이다',
#   '요',
#   '매우',
#   '재미있다'],
#  ['네', '코파', '라', '시리즈', '는', '스팀', '야겜', '필수', '목록', '순위', '이다'],
#  ['뭔가', '깨다', '어렵다'],
#  ['모르다', '그냥', '배그', '보다', '재밌다', '헤헿'],
#  ['그래서', '여우', '새끼', '는', '어딨다'],
#  ['리듬게임', '인데', '리듬', '이', '맞다', '않다', '신기', '한게임'],
#  ['싱글플레이',
#   '방방',
#   '뛰다',
#   '연속',
#   '킬',
#   '을',
#   '딸때',
#   '의',
#   '쾌감',
#   '은',
#   '진짜',
#   '인정',
#   '타임',
#   '어택',
#   '그래도',
#   '속',
#   '도감',
#   '은',
#   '속',
#   '도감',
#   '인지',
#   '라',
#   '도전',
#   '욕구',
#   '는',
#   '생기다',
#   '그렇다',
#   '생기다',
#   '야',
#   '발',
#   '멀티플레이',
#   '안',
#   '해보다'],
#  ['배경음악', '굿'],
#  ['나', '만', '이', '게임', '오른쪽', '컨트롤', '키', '없다', '못', '하다'],
#  ['웜',
#   '커엽',
#   '근데',
#   '도움말',
#   '도',
#   '없다',
#   '길찾기',
#   '넘다',
#   '힘드다',
#   '퀘스트',
#   '깨다',
#   '찾다',
#   '돌아다니다',
#   '시간',
#   '더듬다'],
#  ['처음', '에', '목맨', '남자', '애', '보다', '눈뜨다'],
#  ['솔직하다',
#   '미연시',
#   '작품',
#   '그리다',
#   '자다',
#   '하다',
#   '않다',
#   '네',
#   '코파',
#   '라',
#   '사쿠라',
#   '스피릿',
#   '등',
#   '모두',
#   '시간',
#   '이',
#   '것',
#   '만큼은',
#   '진짜',
#   '명작',
#   '같다',
#   '처음',
#   '으로',
#   '미연시',
#   '라는',
#   '장르',
#   '에',
#   '빠져들다',
#   '작품',
#   '이',
#   '이다'],
#  ['세이브',
#   '파일',
#   '이',
#   '스팀',
#   '클라우드',
#   '에',
#   '동기화',
#   '가',
#   '안되다',
#   '그것',
#   '만',
#   '어떻다',
#   '처리',
#   '되다',
#   '괜찮다',
#   '같다',
#   '스토리',
#   '진행',
#   '하다',
#   '영어',
#   '가',
#   '딸리다',
#   '시간',
#   '정도',
#   '걸리다',
#   '분량',
#   '이',
#   '조금',
#   '짧다',
#   '느낌',
#   '이',
#   '들다',
#   '급전',
#   '개',
#   '라는',
#   '느낌'],
#  ['무섭다', '후', '덜덜', '간이', '커지다', '다시', '해보다'],
#  ['쟝게파'],
#  ['영어', '알다', '재밌다', '구리다', '게임', '아니다', '좋다'],
#  ['컨텐츠', '가', '없다'],
#  ['사람', '이', '없다'],
#  ['비추다',
#   '하다',
#   '오픈',
#   '첫날',
#   '주말',
#   '내내',
#   '서버',
#   '닫다',
#   '두다',
#   '기술',
#   '력',
#   '에',
#   '감탄',
#   '하고',
#   '가다'],
#  ['옛날', '에', '많이', '하다', '다시', '해보다', '여전하다', '재밌다'],
#  ['길', '찾다', '개', '빡치다', '기다', '성격', '급하다', '사람', '은', '하다'],
#  ['하다',
#   '놈',
#   '몰다',
#   '빵',
#   '하다',
#   '키우다',
#   '죽다',
#   '멘탈',
#   '도',
#   '검투사',
#   '대가리',
#   '나르다',
#   '나르다',
#   '감'],
#  ['암', '워킹', '인더', '레인'],
#  ['망겜',
#   '이라',
#   '그리다',
#   '말',
#   '하다',
#   '어떻다',
#   '초딩',
#   '이',
#   '부들부들',
#   '거리',
#   '면서',
#   '비추다',
#   '누르다'],
#  ['강렬하다', '네온사인', '에', '눈', '이', '멀다', '버리다'],
#  ['서로', '죽', '이며', '지랄', '하다', '게임'],
#  ['탭키',
#   '로',
#   '유저',
#   '정보',
#   '보다',
#   '항상',
#   '열',
#   '에',
#   '네다섯',
#   '명',
#   '은',
#   '애니',
#   '프사',
#   '달다',
#   '씹덕',
#   '들',
#   '어디',
#   '서나',
#   '한글',
#   '만',
#   '고집',
#   '하다',
#   '외국인',
#   '에게',
#   '당당하다',
#   '한글',
#   '로',
#   '대화',
#   '하다',
#   '코충',
#   '이',
#   '캐',
#   '주얼',
#   '에서도',
#   '눕스거리',
#   '며',
#   '뉴비',
#   '배척',
#   '정치',
#   '지다',
#   '고이',
#   '다',
#   '못',
#   '하다',
#   '썩다',
#   '물들다',
#   '완죤',
#   '뭐',
#   '하나',
#   '빠지다',
#   '것',
#   '없이',
#   '완벽하다',
#   '갓',
#   '겜',
#   '이자',
#   '너'],
#  ['나쁘다', '않다', '엔딩', '을', '꼭', '그렇다', '하다', '하다', '의문'],
#  ['인원',
#   '이',
#   '이',
#   '라는',
#   '점',
#   '이',
#   '조금',
#   '아쉽다',
#   '빼다',
#   '다',
#   '좋다',
#   '약간',
#   '어설프다',
#   '그래픽',
#   '과',
#   '쓸데없다',
#   '디테일',
#   '들',
#   '이',
#   '거꾸로',
#   '매력',
#   '포인트',
#   '임'],
#  ['공략',
#   '을',
#   '보다',
#   '어렵다',
#   '초반',
#   '부터',
#   '이르다',
#   '후반',
#   '에선',
#   '어떻다',
#   '두렵다',
#   '끝',
#   '까지',
#   '못',
#   '하다'],
#  ['이제',
#   '당신',
#   '은',
#   '년',
#   '의',
#   '미국',
#   '을',
#   '만들다',
#   '수',
#   '있다',
#   '물론',
#   '건너편',
#   '의',
#   '중국',
#   '이',
#   '거대하다',
#   '건',
#   '예',
#   '외지',
#   '만',
#   '요'],
#  ['어렵다',
#   '이런',
#   '겜',
#   '을',
#   '좋아하다',
#   '터',
#   '라',
#   '넘다',
#   '재다',
#   '이런',
#   '겜',
#   '또',
#   '있다',
#   '좋다'],
#  ['서버', '어디', '감', '미아', '요', '엉엉'],
#  ['처음',
#   '시작',
#   '하',
#   '면',
#   '화면',
#   '이',
#   '회색',
#   '이다',
#   '회색',
#   '화면',
#   '에',
#   '돌아다니다',
#   '보다',
#   '산이',
#   '랑',
#   '들이다',
#   '나',
#   '요',
#   '네',
#   '여',
#   '돌아다니다',
#   '경치',
#   '구경',
#   '하다',
#   '게임',
#   '인',
#   '것',
#   '같다',
#   '일단',
#   '추천',
#   '누르다',
#   '아직',
#   '개발',
#   '게임',
#   '이라',
#   '그렇다',
#   '같다',
#   '좀더',
#   '개발',
#   '되다',
#   '해보다',
#   '겠다'],
#  ['레디', '하다', '법좀', '알다', '제발'],
#  ['오',
#   '이',
#   '거',
#   '쫌',
#   '만',
#   '더',
#   '추가',
#   '하다',
#   '추가',
#   '하다',
#   '재밌다',
#   '듯',
#   '은',
#   '개뿔',
#   '좋다',
#   '쓰다',
#   '서버',
#   '무한',
#   '로딩'],
#  ['버그', '가', '심하다', '게임', '이', '힘드다'],
#  ['기분',
#   '좋다',
#   '한글',
#   '로',
#   '플레이',
#   '를',
#   '하다',
#   '즐겁다',
#   '플레이',
#   '마지막',
#   '쯤',
#   '설마',
#   '이',
#   '걸',
#   '로',
#   '끝일',
#   '끄다',
#   '라는',
#   '생각',
#   '을',
#   '좀',
#   '많이',
#   '하다',
#   '돼다',
#   '정말로',
#   '끝나다',
#   '볼륨',
#   '은',
#   '좀',
#   '아쉽다',
#   '전체',
#   '적',
#   '으로',
#   '만족하다'],
#  ['재미',
#   '는',
#   '있다',
#   '플레이',
#   '하다',
#   '난데없이',
#   '잠수',
#   '로',
#   '강퇴',
#   '당하다',
#   '킁',
#   '좆목질',
#   '노답'],
#  ['애초',
#   '에',
#   '게임',
#   '을',
#   '사고',
#   '깔다',
#   '하다',
#   '하다',
#   '실하다',
#   '오류',
#   '라면',
#   '서',
#   '실행',
#   '조차',
#   '않다',
#   '돼다'],
#  ['아니다',
#   '아무',
#   '것',
#   '도',
#   '않다',
#   '하다',
#   '무슨',
#   '타다',
#   '소프트웨어',
#   '썻다',
#   '고',
#   '년',
#   '정지',
#   '야',
#   '망겜'],
#  ['뭐',
#   '이렇다',
#   '허다',
#   '졉',
#   '한게임',
#   '이',
#   '난생',
#   '첨으로',
#   '이렇게',
#   '조작',
#   '이',
#   '조잡하다',
#   '게임',
#   '은',
#   '처음'],
#  ['저화질',
#   '비',
#   '한글',
#   '이다',
#   '짧다',
#   '않다',
#   '편',
#   '인데',
#   '숨은그림찾기',
#   '장면',
#   '이',
#   '넘다',
#   '짜증나다',
#   '웬만하다',
#   '다른',
#   '유명하다',
#   '게임',
#   '들',
#   '을',
#   '추천',
#   '하다'],
#  ['게속', '에러', '가', '뜨다', '실행', '이', '안되다', '사양', '이', '되다', '데도'],
#  ['좀', '더', '해보다', '알', '것', '같다'],
#  ['석상', '이', '알다'],
#  ['고',
#   '인물',
#   '이',
#   '잔뜩',
#   '인',
#   '건',
#   '그렇다고',
#   '치고',
#   '최소한',
#   '서버',
#   '는',
#   '관리',
#   '좀',
#   '해주다',
#   '나오다',
#   '얼마나',
#   '지나다',
#   '상대',
#   '는',
#   '멀쩡하다',
#   '푱푱푱',
#   '잘만',
#   '쌓다',
#   '나',
#   '만',
#   '블록',
#   '생',
#   '성',
#   '에',
#   '초',
#   '정도',
#   '걸리다',
#   '뭐',
#   '지',
#   '재다',
#   '공장',
#   '에서',
#   '블록',
#   '찍어내다',
#   '나',
#   '는',
#   '수',
#   '작업',
#   '으로',
#   '만들다',
#   '아니다'],
#  ['이고', '리', '로딩', '하다', '법', '안', '알다', '환불', '하다'],
#  ['옛날',
#   '에',
#   '하다',
#   '포켓몬스터',
#   '같다',
#   '게임',
#   '이다',
#   '엔딩',
#   '은',
#   '두',
#   '개',
#   '고',
#   '재밌다',
#   '힌데',
#   '이',
#   '거',
#   '만들다',
#   '새끼',
#   '정신',
#   '세계',
#   '가',
#   '궁금하다'],
#  ['핵', '존나', '많다', '투표', '기능', '은', '비', '활성화', '되다', '하다', '셈'],
#  ['전작',
#   '의',
#   '결말',
#   '도',
#   '굉장하다',
#   '난해하다',
#   '끝나다',
#   '찜찜하다',
#   '그',
#   '찜찜하다',
#   '해소',
#   '시키다',
#   '게',
#   '아니다',
#   '배',
#   '가',
#   '시키다',
#   '듯',
#   '한',
#   '느낌',
#   '결국',
#   '또',
#   '같다',
#   '적',
#   '과',
#   '같다',
#   '분위기',
#   '와',
#   '같다',
#   '전투',
#   '를',
#   '데자뷰',
#   '처럼',
#   '반복',
#   '하다',
#   '건',
#   '절대',
#   '사양',
#   '하고',
#   '싶다'],
#  ['게임', '은', '재밌다', '편이', '나오다', '그렇다'],
#  ['아',
#   '레이싱',
#   '게임',
#   '은',
#   '제',
#   '가',
#   '환불',
#   '을',
#   '웬만하다',
#   '안',
#   '하다',
#   '파나텍',
#   '에서',
#   '포스',
#   '피드백',
#   '이',
#   '전혀',
#   '느껴지다',
#   '않다',
#   '모션',
#   '피드백',
#   '도',
#   '음',
#   '네',
#   '그냥',
#   '사지',
#   '말다',
#   '프레임',
#   '도',
#   '프레임',
#   '돈',
#   '까지',
#   '덤',
#   '으로',
#   '주다',
#   '안',
#   '갖다',
#   '게임'],
#  ['운빨망겜',
#   '능지',
#   '부족',
#   '망겜',
#   '자신',
#   '의',
#   '운빨',
#   '과',
#   '능지',
#   '를',
#   '테스트',
#   '하다',
#   '수',
#   '있다'],
#  ['시간', '플레이', '동안', '요정', '이', '한번', '도', '안', '나오다', '갓', '게임', '이다'],
#  ['하', '이', '걸', '뭐라다', '하다', '나', '그냥', '사다'],
#  ['골수',
#   '팬심',
#   '으로써',
#   '의',
#   '플레이',
#   '와',
#   '커버',
#   '에도',
#   '한계',
#   '가',
#   '있다',
#   '법',
#   '이',
#   '번작',
#   '은',
#   '이미',
#   '포기',
#   '한지',
#   '오',
#   '래지',
#   '만',
#   '곧',
#   '나오다',
#   '사',
#   '쇼',
#   '신작',
#   '의',
#   '그래픽',
#   '을',
#   '보고',
#   '다음',
#   '늘다',
#   '기대하다',
#   '한',
#   '가치',
#   '가',
#   '생기다',
#   '그렇다',
#   '하다',
#   '나오다',
#   '기다리다',
#   '겁니다'],
#  ['게임',
#   '을',
#   '잘',
#   '만들다',
#   '보다',
#   '헬',
#   '조선',
#   '운영',
#   '이',
#   '얼마나',
#   '게임',
#   '을',
#   '망치다',
#   '있다',
#   '보여주다',
#   '게임',
#   '거기',
#   '에',
#   '아무리',
#   '보다',
#   '운영',
#   '진',
#   '이',
#   '쪽바리'],
#  ['써버', '개판'],
#  ['하다',
#   '하다',
#   '가사',
#   '있다',
#   '노래',
#   '는',
#   '대부분',
#   '중국어',
#   '대만어',
#   '고',
#   '리듬게임',
#   '인데',
#   '굳이',
#   '배경',
#   '을',
#   '번쩍번쩍',
#   '화려하다',
#   '만들다',
#   '필요',
#   '가',
#   '있다',
#   '싶다',
#   '눈',
#   '도',
#   '아프다',
#   '가시',
#   '성도',
#   '떨어지다'],
#  ['년도',
#   '때',
#   '나오다',
#   '게임',
#   '으론',
#   '이렇다',
#   '발상',
#   '은',
#   '최고',
#   '이다',
#   '생존',
#   '게임',
#   '의',
#   '최고',
#   '라',
#   '고도',
#   '생각',
#   '되다',
#   '다만',
#   '잦다',
#   '크래쉬',
#   '와',
#   '버그',
#   '는',
#   '단점',
#   '이',
#   '되다',
#   '의',
#   '특성',
#   '상',
#   '레벨',
#   '을',
#   '올리다',
#   '욕심',
#   '에',
#   '불법',
#   '프로그램',
#   '을',
#   '사용',
#   '하다',
#   '유저',
#   '들',
#   '에',
#   '감점',
#   '이',
#   '되다'],
#  ['고렙', '과금', '충', '노', '닝겐'],
#  ['메', '에', '에', '에', '에', '에'],
#  ['같다'],
#  ['잡것', '들', '때문', '에', '못', '하다', '먹다'],
#  ['월',
#   '탱',
#   '보다야',
#   '블리츠',
#   '가',
#   '훨씬',
#   '훠',
#   '어어',
#   '어',
#   '얼씬',
#   '티어',
#   '올',
#   '리기',
#   '는',
#   '빠르다',
#   '이',
#   '것',
#   '마저도',
#   '무',
#   '과금',
#   '이',
#   '티어',
#   '가기',
#   '엔',
#   '상당하다',
#   '많다',
#   '시간',
#   '이',
#   '소요',
#   '되다'],
#  ['여기',
#   '게임',
#   '들',
#   '이',
#   '다',
#   '비슷하다',
#   '무난',
#   '하다',
#   '플레이',
#   '하다',
#   '이번',
#   '건',
#   '스토리',
#   '가',
#   '별로',
#   '이다'],
#  ['이',
#   '게임',
#   '을',
#   '통해',
#   '자신',
#   '의',
#   '성',
#   '정체',
#   '성',
#   '을',
#   '알아보다',
#   '좋다',
#   '시간',
#   '을',
#   '만들다',
#   '보아',
#   '요'],
#  ['비트'],
#  ['추다', '때', '창문', '열다', '하니', '현장', '감', '이', '느껴지다'],
#  ['한글화', '되다', '해봤다', '내', '취향', '에', '맞다', '재밌다', '하다', '읍니', '다'],
#  ['인형', '편', '에서', '죽다', '귀신', '따라다니다', '좋다', '거', '규', '경', '가능'],
#  ['그냥', '구', '버전', '깔다', '하다', '구', '버전', '맛', '을', '살리다'],
#  ['오픈월드', '형식', '의', '퍼즐게임', '퍼즐게임', '좋아하다', '사람', '들', '에게', '추천', '함'],
#  ['더', '많다', '의상', '이', '필요하다'],
#  ['게임',
#   '실행',
#   '이',
#   '안되다',
#   '게임',
#   '실행',
#   '을',
#   '클릭',
#   '하다',
#   '무',
#   '반응',
#   '에',
#   '스팀',
#   '에는',
#   '실행',
#   '중',
#   '으로',
#   '나오다',
#   '아무렇다',
#   '창',
#   '도',
#   '뜨다',
#   '않다',
#   '작업',
#   '관리자',
#   '에서',
#   '서비스',
#   '에',
#   '들어가다',
#   '가다',
#   '실행',
#   '중',
#   '인데',
#   '시작',
#   '은',
#   '안되다'],
#  ['우리', '의', '미래', '가', '되다', '않다'],
#  ['아주', '훌륭하다', '소프트웨어', '다', '창작', '마당', '만', '빼다'],
#  ['무료', '퍼즐게임', '이다', '그냥', '하다', '한', '무료', '퍼즐게임'],
#  ['아주', '그냥', '개', '적', '화가', '쩔다', '버리다'],
#  ['난',
#   '많다',
#   '바라지',
#   '않다',
#   '게임',
#   '은',
#   '재밌다',
#   '멀미',
#   '유발',
#   '이',
#   '너무',
#   '심하다',
#   '오래',
#   '못',
#   '앉다'],
#  ['구르다', '치다', '맞다', '개시', '발'],
#  ['대다수',
#   '분',
#   '들',
#   '이',
#   '추천',
#   '하다',
#   '게임',
#   '이나',
#   '나',
#   '는',
#   '별로',
#   '다',
#   '화면',
#   '은',
#   '아름답다',
#   '만화',
#   '같다',
#   '이상하다',
#   '손맛',
#   '이',
#   '별로',
#   '다',
#   '결말',
#   '을',
#   '보다',
#   '울다',
#   '겨자',
#   '먹기',
#   '로',
#   '꾸역꾸역',
#   '진행',
#   '하다',
#   '마지막',
#   '을',
#   '보다',
#   '바이오쇼크',
#   '편도',
#   '하다',
#   '때리다',
#   '치다',
#   '바이오쇼크',
#   '가',
#   '안',
#   '맞다',
#   '사람',
#   '에게는',
#   '별로',
#   '네',
#   '요'],
#  ['라이브러리', '에', '묻히다', '쿠소', '게'],
#  ['제품',
#   '의',
#   '표지',
#   '의',
#   '돼지',
#   '의',
#   '얼굴',
#   '과는',
#   '달리',
#   '인',
#   '게임',
#   '에서의',
#   '돼지',
#   '의',
#   '얼굴',
#   '은',
#   '놀라다',
#   '순하다',
#   '생기다'],
#  ['친구',
#   '와',
#   '하다',
#   '좋다',
#   '게임',
#   '한글화',
#   '걸다',
#   '넘어지다',
#   '사람',
#   '이',
#   '있다',
#   '사실',
#   '없다',
#   '다',
#   '알',
#   '아들',
#   '을',
#   '정도',
#   '는',
#   '되다',
#   '편'],
#  ['여러분', '이', '언제', '스키', '를', '익스트림', '하다', '타', '보다'],
#  ['세',
#   '모',
#   '덕',
#   '님',
#   '방송',
#   '보고',
#   '알다',
#   '생각',
#   '보다',
#   '너무',
#   '재미있다',
#   '처',
#   '크다',
#   '표정',
#   '이나',
#   '몹',
#   '들',
#   '의',
#   '행동',
#   '들',
#   '이',
#   '너무',
#   '귀엽다',
#   '게임'],
#  ['정신병'],
#  ['쓸다', '닦다', '정돈', '되다', '좋아하다', '해보다', '만', '하다', '않다'],
#  ['아니다',
#   '무슨',
#   '시',
#   '이',
#   '이발',
#   '조온나',
#   '아',
#   '게임',
#   '을',
#   '실행',
#   '시키다',
#   '기도',
#   '전',
#   '에',
#   '무슨',
#   '어류',
#   '가',
#   '뜨다',
#   '만원',
#   '그녕',
#   '날다',
#   '먹다'],
#  ['올해',
#   '월',
#   '쯤',
#   '공식',
#   '한글화',
#   '되다',
#   '한글패치',
#   '만들다',
#   '분',
#   '블로그',
#   '는',
#   '닫히다',
#   '전',
#   '관짝',
#   '으로',
#   '들어가다'],
#  ['재밌다',
#   '이',
#   '게',
#   '재밌다',
#   '이',
#   '거',
#   '재밌다',
#   '사람',
#   '들',
#   '넷마블',
#   '틀리다',
#   '그림',
#   '찾기',
#   '해보다',
#   '진짜',
#   '개',
#   '꿀잼'],
#  ['한때',
#   '인생게임',
#   '이다',
#   '금요일',
#   '밤',
#   '에',
#   '시작',
#   '하다',
#   '밤새다',
#   '플레이',
#   '하다',
#   '하다',
#   '그렇지만',
#   '르귄',
#   '패치',
#   '이후',
#   '로는',
#   '도저히',
#   '게임',
#   '을',
#   '하다',
#   '어렵다',
#   '되어다',
#   '게임',
#   '복잡',
#   '성',
#   '이',
#   '너무',
#   '올라가다',
#   '함대',
#   '는',
#   '대규모',
#   '편성',
#   '이나',
#   '유지',
#   '가',
#   '어려워지다',
#   '그래서',
#   '게임',
#   '을',
#   '지우다',
#   '버리다'],
#  ['게놈',
#   '아프다',
#   '토사',
#   '우르',
#   '스',
#   '마리',
#   '부화',
#   '시키다',
#   '과학',
#   '미션',
#   '중이',
#   '이다',
#   '게놈',
#   '로',
#   '아직',
#   '완성',
#   '도',
#   '못',
#   '하다',
#   '발굴',
#   '지',
#   '고갈',
#   '로',
#   '뜨다',
#   '무엇',
#   '버그',
#   '망겜'],
#  ['트라',
#   '인',
#   '시리즈',
#   '가다',
#   '너무',
#   '재밌다',
#   '기대하다',
#   '진심',
#   '하다',
#   '말다',
#   '늘다',
#   '시리즈',
#   '중',
#   '에',
#   '마지막',
#   '인데',
#   '이',
#   '거',
#   '는',
#   '뭐',
#   '스토리',
#   '가',
#   '분',
#   '도',
#   '안되다',
#   '꺠',
#   '고',
#   '진짜',
#   '스토리',
#   '형편',
#   '없다',
#   '진심',
#   '으로',
#   '덜',
#   '닦다',
#   '느낌',
#   '남',
#   '트',
#   '라인',
#   '시리즈',
#   '는',
#   '끄다'],
#  ['조', '작', '감', '이', '좀', '더', '부드럽다', '좋다'],
#  ['소개', '영상', '을', '보고', '오다', '다', '압니', '다', '근데', '그렇다', '일', '없다', '겁니다'],
#  ['게임',
#   '이',
#   '너무',
#   '불친절하다',
#   '게임',
#   '적',
#   '인',
#   '허용',
#   '으로',
#   '넘어가다',
#   '안',
#   '넘어가다',
#   '튜토리얼',
#   '과정',
#   '에서',
#   '뭐',
#   '가',
#   '문제',
#   '면',
#   '툴팁',
#   '으로',
#   '알다',
#   '그렇다',
#   '하나',
#   '도',
#   '없다',
#   '환불',
#   '함'],
#  ['청소', '시작', '물', '쏟다', '멘붕', '재개', '또', '쏟다', '빡종'],
#  ['전작', '의', '명성', '에', '맞다', '확실하다', '재밌다', '전보', '다', '더', '어려워지다'],
#  ['재미',
#   '는',
#   '있다',
#   '아군',
#   '지휘',
#   '관',
#   '을',
#   '보다',
#   '프래깅',
#   '이',
#   '왜',
#   '생기다',
#   '알다',
#   '같다',
#   '결국',
#   '혼자',
#   '서',
#   '마리',
#   '는',
#   '잡지',
#   '않다',
#   '전선',
#   '유지',
#   '조차',
#   '안되다',
#   '아군',
#   '은',
#   '보이지',
#   '도',
#   '않다',
#   '멍청하다',
#   '멍청하다',
#   '재미있다',
#   '와아',
#   '악'],
#  ['쓸다', '때', '업다', '사지', '마여'],
#  ['갑자기',
#   '겜',
#   '실행',
#   '이',
#   '전혀',
#   '안되다',
#   '오류',
#   '코드',
#   '는',
#   '인데',
#   '시바',
#   '뭐',
#   '가',
#   '문제',
#   '인지',
#   '진짜',
#   '좆망',
#   '겜',
#   '수준',
#   '은',
#   '어디',
#   '안',
#   '가다'],
#  ['왜', '플레이', '하다', '렉', '걸리다', '기술', '멋지다', '급습', '멋지다', '스토리'],
#  ['모바일',
#   '버전',
#   '과',
#   '플래시',
#   '버전',
#   '두다',
#   '해봤다',
#   '불구',
#   '하고',
#   '오토',
#   '마우스',
#   '대체',
#   '미지',
#   '원',
#   '은',
#   '욕처',
#   '먹다',
#   '쌈'],
#  ['이',
#   '게임',
#   '은',
#   '스토리',
#   '부터',
#   '캐릭터',
#   '맵',
#   '그',
#   '모든',
#   '것',
#   '을',
#   '서든어택',
#   '배',
#   '끼다',
#   '서든어택',
#   '이',
#   '더',
#   '재미있다',
#   '스레기겜',
#   '노잼',
#   '사다',
#   '샘',
#   '후회',
#   '함',
#   '환',
#   '불'],
#  ['일단',
#   '개',
#   '같다',
#   '애',
#   '요',
#   '좀',
#   '많이',
#   '개',
#   '같다',
#   '애',
#   '요',
#   '그',
#   '니깐',
#   '개',
#   '같다',
#   '애',
#   '요',
#   '아무튼',
#   '개',
#   '같다',
#   '임'],
#  ['무료', '플레이', '인데', '한글', '이라고', '적히다', '한글', '플레이', '가', '안되다', '개', '노답'],
#  ['어지럽다', '못', '하다', '왜삿', '지'],
#  ['한글', '지', '원', '좀', '해주다', '한', '섭', '도', '망하다'],
#  ['자동차', '매니아', '에겐', '신의', '축복', '같다', '게임'],
#  ['딱',
#   '한마디',
#   '만',
#   '하다',
#   '이',
#   '게임',
#   '하고',
#   '시',
#   '계보',
#   '니',
#   '아침',
#   '시',
#   '겁나다',
#   '재밌다',
#   '아',
#   '옛날',
#   '퀘이크',
#   '하다',
#   '시절',
#   '도',
#   '떠오르다',
#   '울',
#   '펜',
#   '이나',
#   '두다',
#   '캐릭터',
#   '도',
#   '참전',
#   '하다',
#   '개',
#   '꾸다',
#   '용'],
#  ['조',
#   '작',
#   '방법',
#   '은',
#   '조이패드',
#   '에',
#   '맞추다',
#   '하다',
#   '데타',
#   '격감',
#   '이',
#   '종이',
#   '때리다',
#   '못함'],
#  ['모드', '깔다', '싶다'],
#  ['재밌다', '컨텐츠', '가', '부족하다', '업뎃좀'],
#  ['발전', '가능성', '이', '보이다', '나름', '꾸르잼', '게임'],
#  ['시절',
#   '의',
#   '방황',
#   '하다',
#   '바하',
#   '시리즈',
#   '분명',
#   '재미',
#   '는',
#   '있다',
#   '액션',
#   '도',
#   '공포',
#   '도',
#   '스토리',
#   '도',
#   '묘',
#   '하다',
#   '조금씩',
#   '부족함',
#   '할인',
#   '때',
#   '구매',
#   '하다',
#   '것',
#   '을',
#   '추천'],
#  ['적어도',
#   '풀',
#   '스크린',
#   '이랑',
#   '오버레이',
#   '지원',
#   '그리고',
#   '키',
#   '설정',
#   '은',
#   '좀',
#   '지원',
#   '을',
#   '하다',
#   '하다',
#   '거',
#   '아니다',
#   '게임',
#   '이',
#   '너무',
#   '불친절하다'],
#  ['김', '나', '성보고', '하다'],
#  ['중력', '시스템', '너무', '답답하다', '못', '하다'],
#  ['저', '지금', '울다'],
#  ['진부하다',
#   '러브스토리',
#   '지만',
#   '스토리',
#   '를',
#   '크게',
#   '신경',
#   '쓰다',
#   '않다',
#   '배경',
#   '이',
#   '재미있다',
#   '신나다',
#   '와우',
#   '퀴즈',
#   '풀다',
#   '가',
#   '빡',
#   '이',
#   '치다',
#   '있다',
#   '힌트',
#   '를',
#   '보다',
#   '슈팅게임',
#   '공략',
#   '책',
#   '을',
#   '보다',
#   '인터넷',
#   '을',
#   '찾아보다'],
#  ['평가',
#   '들',
#   '을',
#   '보고',
#   '구매',
#   '를',
#   '해보다',
#   '일단',
#   '난',
#   '환불',
#   '을',
#   '하다',
#   '무슨',
#   '게임',
#   '인지',
#   '모르다'],
#  ['의외로', '노잼'],
#  ['왜', '내', '가', '괴물', '하다', '약', '한', '거지'],
#  ['내',
#   '가',
#   '플랫포머',
#   '류',
#   '게임',
#   '을',
#   '싫어하다',
#   '알',
#   '게',
#   '해주다',
#   '게임',
#   '스토리',
#   '심오하다',
#   '뭐',
#   '니',
#   '포장',
#   '들',
#   '하지만',
#   '그냥',
#   '짜임새',
#   '있다',
#   '짜다',
#   '은',
#   '게',
#   '아니다',
#   '알다',
#   '준',
#   '게',
#   '없다',
#   '자기',
#   '들',
#   '끼리',
#   '소설',
#   '쓰다',
#   '뿐이다'],
#  ['재밌다', '고', '인물', '난장판', '게임', '노답'],
#  ['블옵', '가다', '더', '깔끔하다', '재미있다', '같다', '한글화', '아니다', '걸렀을듯'],
#  ['이', '게임', '의', '단점', '은', '조', '작법', '밖에', '없다'],
#  ['솔직하다', '이', '거', '난이도', '가', '씹다', '바', '개', '어렵다'],
#  ['게임',
#   '이',
#   '존망',
#   '이라',
#   '그렇다',
#   '은',
#   '좋다',
#   '원레',
#   '파판',
#   '시리즈',
#   '가',
#   '은',
#   '다',
#   '좋다'],
#  ['가다', '멍청하다', '난이도', '최고', '로', '올리다', '고해', '야', '되다'],
#  ['콘솔',
#   '로',
#   '하다',
#   '음성',
#   '한국어',
#   '인데',
#   '로',
#   '하다',
#   '무조건',
#   '영어',
#   '자막',
#   '도',
#   '없다',
#   '영어',
#   '에',
#   '자신',
#   '있다',
#   '하다'],
#  ['시간', '플레이', '타임', '동안', '뛰어다니다', '시간', '인', '듯', '뜬금없이', '튕', '기다', '덤'],
#  ['도전',
#   '과제',
#   '달성',
#   '도과',
#   '때문',
#   '에',
#   '회차',
#   '극',
#   '초반',
#   '까지',
#   '하다',
#   '나름',
#   '괜찮다',
#   '하지만',
#   '달리기',
#   '가',
#   '없다',
#   '대쉬',
#   '도',
#   '딜레이',
#   '가',
#   '있다',
#   '약간',
#   '의',
#   '불편하다',
#   '전투',
#   '방식',
#   '은',
#   '괜찮다'],
#  ['전설', '의', '시작', '이다', '꼭', '추천', '하다'],
#  ['어렵다', '흑', '흑'],
#  ['이',
#   '게임',
#   '은',
#   '멀티',
#   '를',
#   '지원',
#   '하다',
#   '않다',
#   '이',
#   '게임',
#   '은',
#   '멀티',
#   '를',
#   '지원',
#   '하다',
#   '않다',
#   '이',
#   '게임',
#   '은',
#   '멀티',
#   '를',
#   '지원',
#   '하다',
#   '않다'],
#  ['알다',
#   '없다',
#   '의미',
#   '들',
#   '로',
#   '가득',
#   '찬',
#   '퍼즐게임',
#   '처음',
#   '해보다',
#   '정말',
#   '뭘',
#   '어쩌',
#   '라는',
#   '건지다',
#   '계속',
#   '헤매다',
#   '되다',
#   '진짜',
#   '아',
#   '무것',
#   '도',
#   '알다',
#   '없다',
#   '오랜',
#   '시간',
#   '을',
#   '뻘',
#   '짓거리',
#   '하',
#   '게',
#   '만들다',
#   '색깔',
#   '별로',
#   '독특하다',
#   '꾸미다',
#   '맵',
#   '디자인',
#   '조차도',
#   '없다',
#   '치다',
#   '안',
#   '보다',
#   '게임'],
#  ['를',
#   '좀',
#   '더',
#   '추가',
#   '시키다',
#   '튜토리얼',
#   '도',
#   '좀',
#   '자세하다',
#   '만들다',
#   '초반',
#   '플레이',
#   '에',
#   '도움',
#   '되게',
#   '해주다',
#   '싶다'],
#  ['자동차', '의', '구조', '를', '알다', '매우', '적합하다'],
#  ['분', '딱', '분만', '하다', '벌써', '지리다', '같다', '무섭다'],
#  ['노스',
#   '오브',
#   '더',
#   '워리어',
#   '보단',
#   '적지',
#   '만',
#   '버그',
#   '쩔다',
#   '공략',
#   '때문',
#   '에',
#   '골',
#   '아프다',
#   '주인공',
#   '들',
#   '도',
#   '별로',
#   '년',
#   '넘어가다',
#   '신작',
#   '안',
#   '나오다',
#   '이렇다',
#   '이유',
#   '인가'],
#  ['드론', '때매', '해킹', '을', '하다', '수가', '없다'],
#  ['진행중', '매치', '에', '들어가다', '것좀', '없애다', '제발'],
#  ['와우',
#   '개꿀잼',
#   '이',
#   '거',
#   '마우스',
#   '로',
#   '도',
#   '조종',
#   '이',
#   '가능하다',
#   '미치다',
#   '그리고',
#   '꿀잼'],
#  ['재미', '는', '있다', '고', '인물', '들', '이', '너무', '많다', '좀', '짜증나다'],
#  ['일단',
#   '존나',
#   '개',
#   '적',
#   '화',
#   '다',
#   '좆',
#   '같다',
#   '절대로',
#   '하다',
#   '사양',
#   '낮다',
#   '사람',
#   '들',
#   '은',
#   '비',
#   '추천'],
#  ['좋다',
#   '점',
#   '은',
#   '라라',
#   '크다',
#   '포트',
#   '를',
#   '다시',
#   '만',
#   '날수',
#   '있다',
#   '거',
#   '밖',
#   '에',
#   '없다',
#   '잔',
#   '버그',
#   '까지는',
#   '이해',
#   '하다',
#   '진짜',
#   '스토리',
#   '개',
#   '망',
#   '폐기물',
#   '수준',
#   '쉴드',
#   '를',
#   '치다',
#   '없다',
#   '그냥',
#   '쉴드',
#   '로',
#   '패',
#   '고',
#   '싶다'],
#  ['네트워크',
#   '오류',
#   '때문',
#   '에',
#   '멀티',
#   '를',
#   '못',
#   '하다',
#   '존나',
#   '개',
#   '적',
#   '화',
#   '지리',
#   '네'],
#  ['이', '거', '멀티', '만', '돼다', '비슷하다', '게임', '들', '압살', '하다', '수', '있다'],
#  ['비', '추천'],
#  ['전선',
#   '확장',
#   '및',
#   '에너지',
#   '관리',
#   '를',
#   '소재',
#   '로',
#   '하다',
#   '게임',
#   '서서히',
#   '밀리다',
#   '올라가다',
#   '전선',
#   '을',
#   '보다',
#   '기쁘다',
#   '하다',
#   '수',
#   '있다'],
#  ['쒸익쒸익'],
#  ['사', '보삼', '후회', '는', '안함'],
#  ['예상',
#   '한',
#   '그대로',
#   '의',
#   '내용',
#   '시간',
#   '낭비',
#   '비추다',
#   '차라리',
#   '짱구',
#   '아빠',
#   '영상',
#   '이',
#   '배다',
#   '더',
#   '감동',
#   '적'],
#  ['재밋음', '단지', '어려움', '난이도', '도전', '이', '두렵다'],
#  ['초',
#   '짜다',
#   '용다',
#   '판',
#   '의',
#   '그',
#   '느낌',
#   '그대로',
#   '반드시',
#   '픽셀',
#   '판',
#   '으로',
#   '하다',
#   '것',
#   '스팀',
#   '판',
#   '에',
#   '추가',
#   '되다',
#   '그냥',
#   '그래픽',
#   '모드',
#   '로',
#   '하다',
#   '재미',
#   '가',
#   '반의',
#   '반의',
#   '반도',
#   '안되다',
#   '아쉽다',
#   '점',
#   '이',
#   '라면',
#   '판',
#   '에',
#   '있다',
#   '갤러리',
#   '모드',
#   '가',
#   '사라지다',
#   '으아',
#   '뻐킹'],
#  ['개', '재밌다', '슴', '데헷'],
#  ['휴대폰',
#   '으로',
#   '모모',
#   '랑',
#   '채팅',
#   '하다',
#   '임무',
#   '를',
#   '수행',
#   '하다',
#   '이다',
#   '공포',
#   '게임',
#   '너무',
#   '짧다',
#   '단순하다',
#   '한국어',
#   '지원',
#   '도',
#   '없다',
#   '세',
#   '일',
#   '많이',
#   '하다',
#   '때',
#   '해보다'],
#  ['겜', '시작', '한지', '분만', '애', '버그', '로', '바닥', '으로', '무한', '빨다', '들어가다'],
#  ['게임',
#   '이',
#   '안',
#   '돼다',
#   '무슨',
#   '문제',
#   '인',
#   '지는',
#   '모르다',
#   '튜터링',
#   '이',
#   '끝나다',
#   '보다',
#   '게임',
#   '이',
#   '들어가다',
#   '하얀색',
#   '로딩',
#   '으로',
#   '정지후',
#   '안되다'],
#  ['대충',
#   '복수',
#   '한다는',
#   '내용',
#   '인',
#   '건',
#   '알다',
#   '영어',
#   '라서',
#   '자다',
#   '못',
#   '알다',
#   '먹다',
#   '게다가',
#   '남부',
#   '사투리',
#   '다'],
#  ['아들',
#   '아',
#   '난',
#   '도대체',
#   '이',
#   '게',
#   '뭔',
#   '개',
#   '소린',
#   '지',
#   '알',
#   '아',
#   '먹다',
#   '못',
#   '하다'],
#  ['층', '까지', '내려가다', '왜', '애', '들', '머리', '수집', '하', '냐', '존나', '무섭다'],
#  ['가격', '의', '비', '하다', '너무', '재밌다'],
#  ['유저',
#   '한글화',
#   '는',
#   '사랑',
#   '이다',
#   '스텔스',
#   '도',
#   '라',
#   '우드',
#   '도',
#   '재미있다',
#   '다만',
#   '버그',
#   '때문',
#   '에',
#   '좀',
#   '헤매다',
#   '기억',
#   '이',
#   '있다',
#   '난이도',
#   '는',
#   '제',
#   '기준',
#   '에는',
#   '조',
#   '오금',
#   '있다',
#   '편',
#   '인데',
#   '조절',
#   '이',
#   '가능하다',
#   '좋다'],
#  ['보더',
#   '랜드',
#   '시리즈',
#   '에',
#   '진짜',
#   '극도',
#   '의',
#   '애정',
#   '이',
#   '있다',
#   '아니다',
#   '이상',
#   '건너',
#   '뛰다',
#   '무방',
#   '한',
#   '편임',
#   '그래도',
#   '나',
#   '에서',
#   '언급',
#   '이',
#   '되다',
#   '보스',
#   '가',
#   '여기',
#   '보스',
#   '이기도',
#   '하다',
#   '싼값',
#   '으로',
#   '할인',
#   '하다',
#   '사서',
#   '해보다',
#   '나쁘다',
#   '않다'],
#  ['짧다',
#   '즐',
#   '기기',
#   '에는',
#   '좋다',
#   '달성',
#   '은',
#   '매우',
#   '귀찮다',
#   '주차',
#   '나',
#   '진행',
#   '하다',
#   '단순',
#   '반복',
#   '뿐',
#   '이라',
#   '흥미',
#   '가',
#   '떨어지다'],
#  ['왜',
#   '이',
#   '게',
#   '블랙',
#   '옵스',
#   '인가',
#   '아직도',
#   '모르다',
#   '그냥',
#   '좀비',
#   '겜',
#   '된거',
#   '같다',
#   '늘다',
#   '언제나',
#   '폭망'],
#  ['윈도우',
#   '으로',
#   '구',
#   '동시',
#   '처음',
#   '화면',
#   '에서',
#   '깜박',
#   '거림',
#   '이',
#   '존재',
#   '하다',
#   '게임',
#   '안',
#   '에서',
#   '건물',
#   '을',
#   '건설',
#   '하다',
#   '스크린샷',
#   '처럼',
#   '화면',
#   '이',
#   '렉',
#   '이',
#   '걸리다',
#   '한',
#   '상황',
#   '이',
#   '발생',
#   '하다',
#   '다른',
#   '지역',
#   '에',
#   '가다',
#   '그',
#   '현상',
#   '은',
#   '사라지다',
#   '상당하다',
#   '거슬리다',
#   '그',
#   '외',
#   '에는',
#   '재미있다',
#   '플레이',
#   '하다'],
#  ['지금', '생각', '해보다', '왜', '사다', '후회', '중', '워해머', '살껄'],
#  ['이',
#   '시리즈',
#   '는',
#   '안',
#   '하다',
#   '되다',
#   '하다',
#   '내내',
#   '짜증',
#   '과',
#   '지루함',
#   '이',
#   '가득하다',
#   '스토리',
#   '도',
#   '짜증나다',
#   '계속',
#   '등장',
#   '하다',
#   '딸',
#   '들',
#   '은',
#   '이야기',
#   '를',
#   '아주',
#   '루즈',
#   '하다',
#   '만',
#   '드',
#   '네',
#   '요'],
#  ['훌륭하다', '협동', '게임'],
#  ['이다', '전', '은', '미국', '에서', '어', '구요', '인', '게인', '어더껀', '하다', '몬으게서', '요'],
#  ['스팀',
#   '출시',
#   '한지',
#   '얼마나',
#   '지나다',
#   '아직도',
#   '멀티',
#   '가',
#   '제대로',
#   '안되다',
#   '멀티',
#   '지향',
#   '게임',
#   '은',
#   '무슨',
#   '강제',
#   '솔로',
#   '잉',
#   '게임'],
#  ['남다',
#   '목소리',
#   '졸',
#   '라',
#   '좆',
#   '병신임',
#   '하반신마비',
#   '라',
#   '제데로',
#   '걷다',
#   '못함',
#   '한마디',
#   '로',
#   '인생헛살',
#   '은',
#   '으',
#   '바리',
#   '색기'],
#  ['설정', '창', '에서', '어치', '브먼트', '플', '리즈', '입력', '하다', '도전', '과제', '줌'],
#  ['전체',
#   '적',
#   '으로',
#   '깔끔하다',
#   '친절하다',
#   '배경',
#   '캐릭터',
#   '스토리',
#   '전부',
#   '마음',
#   '에',
#   '들다',
#   '하지만',
#   '전투',
#   '시스템',
#   '은',
#   '익숙해지다',
#   '오랜',
#   '시간',
#   '이',
#   '걸리다',
#   '쾌적하다',
#   '전투',
#   '를',
#   '하다',
#   '꽤',
#   '오랜',
#   '시간',
#   '이',
#   '걸리다',
#   '정통',
#   '중',
#   '에선',
#   '손',
#   '에',
#   '꼽',
#   '을',
#   '정도',
#   '로',
#   '완성',
#   '도',
#   '가',
#   '높다'],
#  ['무한',
#   '로딩',
#   '좀',
#   '고치',
#   '라고',
#   '족',
#   '같다',
#   '진짜',
#   '로',
#   '그리고',
#   '왜',
#   '계속',
#   '빨핑',
#   '만',
#   '처',
#   '잡히다',
#   '진짜',
#   '개화',
#   '나다',
#   '문의',
#   '도',
#   '못',
#   '하다',
#   '진짜',
#   '짜다',
#   '진짜',
#   '니',
#   '자',
#   '릱'],
#  ['조작',
#   '열',
#   '라',
#   '불편하다',
#   '근데',
#   '플스',
#   '패드',
#   '는',
#   '왜',
#   '안',
#   '먹다',
#   '알다',
#   '사람',
#   '검색',
#   '해보다',
#   '안',
#   '나오다'],
#  ['어떻다', '하다', '건지다', '도', '모르다', '재밋엇는', '보', '여서', '살다'],
#  ['재미',
#   '도',
#   '없다',
#   '억지로',
#   '하다',
#   '시간',
#   '이',
#   '남아도',
#   '하다',
#   '말',
#   '하야',
#   '하다',
#   '게임',
#   '인거',
#   '같다'],
#  ['옛', '게임', '의', '향수', '는', '이제', '로', '느끼다'],
#  ['패드',
#   '로',
#   '하다',
#   '버그',
#   '먹다',
#   '게임',
#   '정지',
#   '되다',
#   '냅다',
#   '패드',
#   '던지다',
#   '환불',
#   '하다'],
#  ['중', '병', '같다', '대사', '자다', '버티다', '좋다', '작품', '이다'],
#  ['목욕', '타월', '주인공', '말고', '금발', '드래곤', '을', '주인공', '으로', '뒷', '내용', '덥다'],
#  ['최적화', '좆망'],
#  ['노잼', '라이브러리', '늘리다', '용', '입다'],
#  ['엄청나다',
#   '타',
#   '격감',
#   '수도',
#   '없이',
#   '많다',
#   '무기',
#   '몇',
#   '년',
#   '을',
#   '기다리다',
#   '모르다',
#   '도',
#   '만들다',
#   '줄다'],
#  ['같이', '하다', '분', '게임', '물리엔진', '좆', '같다'],
#  ['아니다',
#   '이런',
#   '경우',
#   '가',
#   '어딨다',
#   '진짜',
#   '돈존',
#   '나다',
#   '뜯다',
#   '사면',
#   '모해',
#   '아이디',
#   '만들다',
#   '또',
#   '들어가다',
#   '아이핀',
#   '만들다',
#   '그',
#   '랜',
#   '늘다',
#   '안되다',
#   '모',
#   '시스템',
#   '을',
#   '이따',
#   '구로',
#   '만들다',
#   '컴퓨터',
#   '잘',
#   '모르다',
#   '모르다',
#   '진짜',
#   '로',
#   '빡치다'],
#  ['별',
#   '생각',
#   '없이',
#   '시간',
#   '때우다',
#   '용',
#   '스토리',
#   '를',
#   '따라가다',
#   '되다',
#   '거기',
#   '때문',
#   '에',
#   '그렇게',
#   '무역',
#   '을',
#   '열심히',
#   '하다',
#   '필요',
#   '가',
#   '없다',
#   '열심히',
#   '하다',
#   '허무하다',
#   '끝나다',
#   '케이스',
#   '딱',
#   '스토리',
#   '에',
#   '필요하다',
#   '만큼만',
#   '얻다',
#   '진행',
#   '하고',
#   '하다',
#   '되다',
#   '거',
#   '같다'],
#  ['처음',
#   '엔',
#   '재미있다',
#   '플레이',
#   '하다',
#   '나중',
#   '에',
#   '가다',
#   '스테이지',
#   '구성',
#   '도',
#   '지루하다',
#   '스토리',
#   '도',
#   '뭔가',
#   '크게',
#   '있다',
#   '것',
#   '같다',
#   '허무하다',
#   '아무튼',
#   '나쁘다',
#   '게임',
#   '이라고',
#   '말',
#   '하다',
#   '좀',
#   '그렇지만',
#   '사서',
#   '하다',
#   '아깝다',
#   '것',
#   '같다'],
#  ['난', '신', '이', '되다', '안되다', '알다', '게임'],
#  ['다',
#   '좋다',
#   '정말',
#   '다',
#   '좋다',
#   '멀티',
#   '플레이',
#   '환경',
#   '은',
#   '최악',
#   '중',
#   '에',
#   '최악',
#   '모든',
#   '장점',
#   '을',
#   '뒤엎',
#   '을',
#   '정도',
#   '로',
#   '화',
#   '딱지',
#   '가',
#   '나서다',
#   '비추다'],
#  ['계속', '하다', '하다', '되다', '재미', '가', '있다'],
#  ['죳', '쓰레기', '코', '박스', '사라'],
#  ['이',
#   '게임',
#   '은',
#   '예전',
#   '에',
#   '사다',
#   '지금',
#   '생각',
#   '하다',
#   '왜',
#   '만들어지다',
#   '의문',
#   '이',
#   '들다',
#   '게임',
#   '이다',
#   '절때',
#   '사다',
# ...
#   '정도',
#   '의',
#   '작품'],
#  ['디펜스', '게임', '을', '즐기다', '신다', '추천'],
#  ['버그', '덩어리'],
#  ['정말', '재미있다', '그런데', '아직', '컨텐츠', '는', '부족'],
#  ['이', '거', '왜', '에러', '뜨다', '실행', '도', '안되다'],
#  ['노', '마더', '게임'],
#  ['한번', '하다', '하다', '없다'],
#  ['원작', '에서', '불만', '이다', '점', '이', '완벽하다', '개선', '되다', '점', '이', '좋다'],
#  ['제대로',
#   '좀',
#   '만들다',
#   '한',
#   '시간',
#   '에',
#   '번',
#   '씩',
#   '은',
#   '튕기',
#   '니',
#   '제대로',
#   '게임',
#   '을',
#   '하다',
#   '수가',
#   '없다',
#   '시간',
#   '넘어서다',
#   '환불',
#   '도',
#   '안되다',
#   '만원',
#   '넘다',
#   '돈',
#   '이',
#   '그냥',
#   '허공',
#   '으로',
#   '날아가다'],
#  ['빨리', '내', '셈'],
#  ['하다',
#   '하나',
#   '서버',
#   '노답',
#   '에',
#   '개',
#   '적',
#   '화',
#   '온갖',
#   '버그',
#   '가',
#   '난무',
#   '하다',
#   '겜',
#   '이돈',
#   '주다',
#   '차라리',
#   '아크',
#   '서바이벌',
#   '이나',
#   '러스트',
#   '를',
#   '하다',
#   '추천',
#   '하다'],
#  ['컨트롤',
#   '더럽다',
#   '불편하다',
#   '왜',
#   '있다',
#   '모르다',
#   '회피',
#   '시스템',
#   '카메라',
#   '돌리다',
#   '불가능하다',
#   '여러분',
#   '은',
#   '싸다',
#   '사지',
#   '말다'],
#  ['역시', '갓', '작품'],
#  ['이',
#   '게임',
#   '시리즈',
#   '는',
#   '전부',
#   '다',
#   '이상하다',
#   '똑같다',
#   '양산',
#   '게임',
#   '이라는',
#   '느낌',
#   '을',
#   '지우다',
#   '힘드다',
#   '퍼즐게임',
#   '인',
#   '척',
#   '하다',
#   '리듬게임',
#   '잦다',
#   '버그',
#   '로',
#   '인하다',
#   '재',
#   '시작',
#   '특히',
#   '마지막',
#   '타다',
#   '버그',
#   '가',
#   '걸리다',
#   '멘붕',
#   '하다',
#   '현상',
#   '이',
#   '노랗다',
#   '벽',
#   '이',
#   '움직',
#   '이지',
#   '말다',
#   '움직이다'],
#  ['많다', '아이템', '과', '제작', '조합', '등', '매우', '컨텐츠', '가', '많다'],
#  ['뭔가',
#   '자다',
#   '만들다',
#   '제자리',
#   '를',
#   '도',
#   '는',
#   '느낌',
#   '잔',
#   '버그',
#   '도',
#   '꽤',
#   '있다',
#   '노가다',
#   '라는',
#   '느낌',
#   '도',
#   '많이',
#   '들다',
#   '제일',
#   '아쉽다',
#   '옆',
#   '동네',
#   '게임',
#   '에',
#   '비다',
#   '던전',
#   '수도',
#   '대략',
#   '개',
#   '로',
#   '한정',
#   '돼다',
#   '마을',
#   '도',
#   '실질',
#   '적',
#   '으로',
#   '이용',
#   '하다',
#   '수',
#   '있다',
#   '늘다',
#   '도서관',
#   '맵',
#   '연습장',
#   '이',
#   '세',
#   '가지',
#   '밖',
#   '에',
#   '없다'],
#  ['화나다'],
#  ['우리나라', '정치', '판', '을', '자다', '묘사', '한', '게임'],
#  ['성장', '의', '재미', '기술', '쓰다', '재미', '가', '있다'],
#  ['아르마', '가다', '더', '좋다'],
#  ['괜히', '조선인', '믿다', '피봄'],
#  ['이',
#   '게임',
#   '의',
#   '분량',
#   '에',
#   '한번',
#   '놀라다',
#   '게임',
#   '클리어',
#   '하다',
#   '때',
#   '춤추다',
#   '보고',
#   '한번',
#   '더',
#   '놀라다'],
#  ['처음',
#   '시',
#   '작',
#   '부분',
#   '에',
#   '꼬리',
#   '아니다',
#   '머리',
#   '하다',
#   '동전',
#   '던지기',
#   '하다',
#   '부분',
#   '에서',
#   '계속',
#   '튕',
#   '기다',
#   '이',
#   '거',
#   '어떻다',
#   '되다',
#   '건지다',
#   '모르다'],
#  ['주사위', '는', '던지다'],
#  ['게임', '을', '하다', '보다', '알', '수', '있다', '아무', '의미', '가', '없다', '것', '을'],
#  ['버스',
#   '가',
#   '왜',
#   '늦',
#   '나',
#   '우리',
#   '지역',
#   '교통',
#   '은',
#   '왜',
#   '이따',
#   '군',
#   '가',
#   '맨날',
#   '욕',
#   '하다',
#   '분',
#   '들',
#   '께',
#   '추천',
#   '하다',
#   '게임',
#   '버스',
#   '를',
#   '빨리',
#   '보내다',
#   '못',
#   '보내다',
#   '교통',
#   '을',
#   '좋다',
#   '만들다',
#   '싶다',
#   '도로',
#   '사정',
#   '때문',
#   '에',
#   '혈압',
#   '만',
#   '오르다',
#   '교통',
#   '회사',
#   '들',
#   '의',
#   '고충',
#   '을',
#   '충분하다',
#   '느끼다',
#   '수',
#   '있다',
#   '게임',
#   '이다'],
#  ['가족', '끼리', '사랑', '에', '빠지다', '게임', '이라니', '망측', '스럽다'],
#  ['이',
#   '거',
#   '어어어어',
#   '어',
#   '엄처',
#   '어어',
#   '엉',
#   '어렵다',
#   '근데',
#   '원',
#   '값',
#   '은',
#   '해',
#   '요',
#   '시간',
#   '훅',
#   '가다'],
#  ['재미없다',
#   '서버',
#   '는',
#   '한자리',
#   '수고',
#   '하다',
#   '사람',
#   '도',
#   '거의',
#   '없다',
#   '이',
#   '거',
#   '하다',
#   '바',
#   '엔',
#   '그',
#   '돈',
#   '아',
#   '끄다',
#   '딴',
#   '겜',
#   '사라',
#   '그래픽',
#   '부터',
#   '모든',
#   '게',
#   '비호감'],
#  ['고블린', '환', '풍구', '버그', '에서', '포기', '하다'],
#  ['음컨텐즈', '너무', '없다'],
#  ['당신',
#   '은',
#   '서부',
#   '시대',
#   '카우보이',
#   '들',
#   '이',
#   '레버액션',
#   '윈체스터',
#   '라이플',
#   '을',
#   '들다',
#   '스핀',
#   '코킹',
#   '하다',
#   '빵빵',
#   '쏘다',
#   '혈투',
#   '를',
#   '동경',
#   '하다'],
#  ['게망겜'],
#  ['재밌다',
#   '가격',
#   '만',
#   '싸다',
#   '좋다',
#   '난',
#   '싸다',
#   '사서',
#   '만족하다',
#   '근데',
#   '욕',
#   '을',
#   '너무',
#   '먹다',
#   '사람',
#   '들',
#   '이',
#   '빠져나가다',
#   '큐',
#   '가',
#   '느리다',
#   '짐'],
#  ['생각', '보다', '플레이', '타임', '도', '좋다', '그렇게', '질리다', '않다', '은근', '히', '꿀잼'],
#  ['플래시',
#   '스마트폰',
#   '타워',
#   '디펜스',
#   '중',
#   '에서',
#   '젤',
#   '추천',
#   '하다',
#   '작품',
#   '난이도',
#   '밸런스',
#   '가',
#   '꽤',
#   '잘',
#   '되다',
#   '지루하다',
#   '않다',
#   '영웅',
#   '업글',
#   '을',
#   '위해',
#   '서',
#   '반복',
#   '이',
#   '아주',
#   '약간',
#   '필요하다',
#   '하지만',
#   '굳이',
#   '디럭스',
#   '나',
#   '에디',
#   '션',
#   '을',
#   '살',
#   '정도',
#   '는',
#   '아니다'],
#  ['현질', '필수'],
#  ['정말',
#   '재미있다',
#   '그런데',
#   '후속작',
#   '은',
#   '안',
#   '나오다',
#   '계속',
#   '만',
#   '나오다',
#   '너무하다',
#   '아니다'],
#  ['멀미', '조심'],
#  ['한글패치', '나오다', '때', '까지', '존버', '하다'],
#  ['컨셉', '은', '좋다', '시드', '마이어', '의', '이름', '값', '이', '아깝다'],
#  ['희다',
#   '대의',
#   '갓',
#   '겜',
#   '그니까',
#   '한글',
#   '패치',
#   '좀',
#   '해주다',
#   '뉴비',
#   '유입',
#   '이',
#   '시급하다',
#   '게임'],
#  ['로그라이크',
#   '게임',
#   '류',
#   '는',
#   '처음',
#   '해보다',
#   '처음',
#   '에',
#   '적응하다',
#   '어렵다',
#   '하다',
#   '하다',
#   '재밌다',
#   '게임',
#   '이다',
#   '재밌다',
#   '하다',
#   '두',
#   '번하다'],
#  ['심플', '하다', '재밌다', '레이싱게임'],
#  ['처음',
#   '플레이',
#   '하다',
#   '때',
#   '그',
#   '공포',
#   '감',
#   '조작',
#   '감',
#   '타',
#   '격감',
#   '을',
#   '잊다',
#   '없다'],
#  ['나폴레옹', '프랑스', '만', '고르다', '있다', '모르다'],
#  ['하다', '졸다', '원정', '도면', '살', '만', '하다'],
#  ['내', '가', '제일', '싫어하다', '몬스터', '피', '하다', '게임'],
#  ['일단', '이', '디', '엘', '씨', '는', '걸다', '야만', '하다', '정말', '구리', '다'],
#  ['역대',
#   '해보다',
#   '콜옵',
#   '중',
#   '가장',
#   '다이나믹',
#   '하다',
#   '벨런스',
#   '가',
#   '자다',
#   '맞추다',
#   '게임',
#   '멀티',
#   '유저',
#   '가',
#   '갈수록',
#   '줄어들다',
#   '너무나도',
#   '아쉽다'],
#  ['할인', '하다', '때', '구매', '하다', '코옵', '으로', '가볍다', '즐', '기기', '엔', '괜찮다', '게임'],
#  ['오다', '버그', '가', '없다', '나', '만'],
#  ['고', '인물', '천지'],
#  ['집중',
#   '하다',
#   '하다',
#   '보다',
#   '분',
#   '이',
#   '끝나다',
#   '정식',
#   '판',
#   '만',
#   '기다리다',
#   '더',
#   '강하다',
#   '총',
#   '이',
#   '필요하다'],
#  ['게임', '은', '재미있다', '엔딩', '이', '좀'],
#  ['년',
#   '만에',
#   '위닝',
#   '을',
#   '구매',
#   '하다',
#   '매번',
#   '평이',
#   '복합',
#   '적',
#   '이르다',
#   '좋다',
#   '않다',
#   '구매',
#   '를',
#   '꺼리다',
#   '오랜',
#   '만',
#   '에',
#   '시리즈',
#   '를',
#   '사서',
#   '해보다',
#   '만족스럽다',
#   '좋다'],
#  ['흠',
#   '재밌다',
#   '조금',
#   '어렵다',
#   '감',
#   '이',
#   '있다',
#   '저',
#   '는',
#   '뒤',
#   '로',
#   '갈수록',
#   '막히다',
#   '공략',
#   '을',
#   '보다'],
#  ['난이도', '가', '너무', '높다'],
#  ['이',
#   '거',
#   '업데이트',
#   '한',
#   '뒤',
#   '로',
#   '갑자기',
#   '문제',
#   '거리',
#   '면서',
#   '온라인',
#   '이',
#   '안되다',
#   '왜',
#   '그런',
#   '거',
#   '죠'],
#  ['뭐', '한글화', '좋다', '지금', '간다', '기다리다'],
#  ['도로시',
#   '한테',
#   '너무',
#   '몰입',
#   '하다',
#   '우울하다',
#   '수도',
#   '있다',
#   '근데',
#   '그거',
#   '빼다',
#   '재밌다',
#   '그레텔',
#   '얼굴',
#   '너무',
#   '무섭다',
#   '일',
#   '내내',
#   '보다',
#   '꿈',
#   '에서',
#   '나오다',
#   '같다',
#   '애',
#   '여'],
#  ['갓', '흥겜', '이다'],
#  ['되게',
#   '재밌다',
#   '보',
#   '여서',
#   '구매',
#   '하다',
#   '설치',
#   '하다',
#   '깔다',
#   '지우다',
#   '몇번',
#   '째',
#   '인지',
#   '모르다',
#   '왜',
#   '자꾸',
#   '작동',
#   '이',
#   '중지',
#   '되어다',
#   '뜨다',
#   '요',
#   '설정',
#   '이',
#   '안',
#   '맞다',
#   '괜히',
#   '돈',
#   '주',
#   '고사',
#   '서',
#   '환불',
#   '하다'],
#  ['시리즈',
#   '물',
#   '은',
#   '꼭',
#   '이어서',
#   '하다',
#   '스타일',
#   '이라',
#   '구매',
#   '하다',
#   '그냥',
#   '클레멘타인',
#   '펜심',
#   '으로',
#   '플레이',
#   '하다'],
#  ['클래식', '한', '게임', '이르다', '슈퍼마리오', '는', '지금', '해도', '재밌다'],
#  ['이',
#   '게임',
#   '하다',
#   '심령',
#   '고자',
#   '가',
#   '되다',
#   '잇다',
#   '를',
#   '느끼다',
#   '정말',
#   '명작',
#   '인거',
#   '같다',
#   '생각',
#   '과',
#   '함께',
#   '게임',
#   '을',
#   '깨',
#   '버리다',
#   '정말',
#   '대',
#   '단',
#   '한게임',
#   '이다'],
#  ['추상',
#   '적',
#   '이고',
#   '상징',
#   '적',
#   '인',
#   '스토리',
#   '가',
#   '간단하다',
#   '퍼즐',
#   '에',
#   '몰입',
#   '하다',
#   '수',
#   '있다',
#   '해주다',
#   '그런데',
#   '지도',
#   '와',
#   '리셋',
#   '버튼',
#   '이',
#   '화면',
#   '에',
#   '뜨다',
#   '않다',
#   '설명',
#   '같다',
#   '것',
#   '들',
#   '도',
#   '뜨다',
#   '않다',
#   '건',
#   '버그',
#   '인가요',
#   '이',
#   '것',
#   '때문',
#   '에',
#   '지도',
#   '가',
#   '필요하다',
#   '관',
#   '부터는',
#   '진행',
#   '이',
#   '안되다'],
#  ['지역', '락', '풀다', '살때', '꼬쇼', '안', '하다', '되다'],
#  ['아직', '개발', '중'],
#  ['탐욕',
#   '이',
#   '개인',
#   '에게',
#   '어떻다',
#   '반영',
#   '되다',
#   '자다',
#   '오다',
#   '닿다',
#   '작품',
#   '이네',
#   '요',
#   '도',
#   '기대',
#   '되다',
#   '추천',
#   '하다'],
#  ['그냥',
#   '설치',
#   '한',
#   '뒤',
#   '에',
#   '게임',
#   '을',
#   '실행',
#   '하',
#   '니까',
#   '검다',
#   '창',
#   '만',
#   '보이',
#   '고',
#   '실행',
#   '이',
#   '안되다'],
#  ['팦바', '개', '훔치다', '간', '새', '기', '들', '때문', '에', '접다'],
#  ['를',
#   '하다',
#   '를',
#   '하다',
#   '왜',
#   '코',
#   '오다',
#   '지다',
#   '들다',
#   '알아듣다',
#   '용어',
#   '쓰다',
#   '지랄',
#   '이다',
#   '난',
#   '게임',
#   '하다',
#   '온',
#   '거지',
#   '병신',
#   '같다',
#   '군사',
#   '용어',
#   '배우다',
#   '온',
#   '게',
#   '아니다'],
#  ['게임',
#   '재밌다',
#   '여러분',
#   '아주',
#   '훌륭하다',
#   '그리고',
#   '새롭다',
#   '시작',
#   '하다',
#   '분',
#   '들',
#   '가문',
#   '어디가',
#   '입하',
#   '실지',
#   '모르다',
#   '저',
#   '한테',
#   '귓말',
#   '보내다',
#   '같이',
#   '천천히',
#   '가보다',
#   '지역',
#   '은',
#   '운천',
#   '이다'],
#  ['맵', '만', '크다', '뭐해', '하다', '없다'],
#  ['얄팍하다',
#   '스페이스',
#   '슈터',
#   '게임',
#   '워낙',
#   '에',
#   '스페이스',
#   '가다',
#   '들어가다',
#   '게임',
#   '중',
#   '복잡하다',
#   '물건',
#   '이',
#   '많다',
#   '보다',
#   '이',
#   '게임',
#   '처럼',
#   '얄팍하다',
#   '것',
#   '도',
#   '나름',
#   '매력',
#   '있다',
#   '장르',
#   '에',
#   '대한',
#   '기초',
#   '적',
#   '인',
#   '지식',
#   '만',
#   '있다',
#   '아주',
#   '가볍다',
#   '즐기다',
#   '수',
#   '있다',
#   '게임'],
#  ['공기청정기',
#   '주인공',
#   '과',
#   '손발',
#   '이',
#   '말리',
#   '비틀어지다',
#   '스토리',
#   '를',
#   '빼다',
#   '나다',
#   '의외로',
#   '하다',
#   '한',
#   '수작',
#   '겜'],
#  ['도저히',
#   '그',
#   '많다',
#   '돈',
#   '을',
#   '들이다',
#   '만들다',
#   '보다',
#   '없다',
#   '퀄리티',
#   '뻔하다',
#   '스토리',
#   '졸작',
#   '도',
#   '아니다',
#   '펀딩할때',
#   '돈',
#   '을',
#   '생각',
#   '하다',
#   '영락',
#   '없다',
#   '졸작',
#   '정말',
#   '딱',
#   '그',
#   '저',
#   '그런',
#   '게임'],
#  ['프레임', '이', '느리다', '같다', '렉', '또는', '끊기다', '현상', '돈', '아깝다', '움'],
#  ['이',
#   '머',
#   '전시',
#   '의',
#   '짝퉁',
#   '게임',
#   '인가',
#   '발',
#   '적',
#   '화',
#   '에',
#   '컨트롤',
#   '도',
#   '엄청',
#   '불편하다',
#   '소방관',
#   '인공',
#   '지능',
#   '이',
#   '너무',
#   '답답하다'],
#  ['푸른',
#   '바다',
#   '속',
#   '을',
#   '돌아다니다',
#   '작살',
#   '을',
#   '쏘다',
#   '물고기',
#   '사냥',
#   '특별하다',
#   '사진',
#   '촬영',
#   '매장',
#   '되다',
#   '보물',
#   '을',
#   '탐색',
#   '하다',
#   '위',
#   '의',
#   '행동',
#   '을',
#   '하다',
#   '돈',
#   '획득',
#   '하다',
#   '수',
#   '있다',
#   '좋다',
#   '장비',
#   '를',
#   '구매',
#   '하다',
#   '수',
#   '있다'],
#  ['게임',
#   '은',
#   '재밌다',
#   '하지만',
#   '개발',
#   '사가',
#   '한글패치',
#   '오',
#   '통수치다',
#   '결국',
#   '한글패치',
#   '무산',
#   '되다'],
#  ['베데스다',
#   '넷',
#   '연동',
#   '하다',
#   '디럭스',
#   '에디',
#   '션',
#   '특전',
#   '안',
#   '뜨다',
#   '도데',
#   '체',
#   '어떻다',
#   '하다',
#   '뜨다',
#   '임'],
#  ['졸라맨', '주제', '에', '타', '격감', '지리', '네'],
#  ['재미있다',
#   '후반',
#   '에',
#   '갈수록',
#   '좀',
#   '지루함',
#   '스토리',
#   '는',
#   '막장',
#   '의',
#   '재미',
#   '깨다',
#   '시간',
#   '정도',
#   '걸리다',
#   '것',
#   '같다',
#   '제',
#   '돈',
#   '주다',
#   '플레이',
#   '하다',
#   '아깝다',
#   '움',
#   '세',
#   '일',
#   '하다',
#   '때',
#   '사시',
#   '고',
#   '늘다',
#   '덕후',
#   '아니다',
#   '필요없다',
#   '함',
#   '난',
#   '안',
#   '사다'],
#  ['뒤지다',
#   '겜',
#   '업뎃',
#   '하',
#   '라고',
#   '하다',
#   '로딩',
#   '걸리다',
#   '계속',
#   '업뎃만뜸',
#   '입구',
#   '컷',
#   '에',
#   '감동',
#   '받다',
#   '비추다',
#   '날리다'],
#  ['아직',
#   '미흡하다',
#   '점',
#   '이',
#   '많다',
#   '얼리다',
#   '억',
#   '세',
#   '스',
#   '이기도',
#   '하다',
#   '많다',
#   '발전',
#   '가능성',
#   '이',
#   '있다',
#   '봄'],
#  ['양민',
#   '학살',
#   '갓',
#   '갓',
#   '발암',
#   '게임',
#   '핵',
#   '유저',
#   '공',
#   '속',
#   '핵',
#   '사용자',
#   '보다',
#   '도',
#   '있다',
#   '갓',
#   '겜임',
#   '초보',
#   '는',
#   '단지',
#   '무기',
#   '재',
#   '조',
#   '재료',
#   '일',
#   '뿐',
#   '이고',
#   '너무',
#   '많이',
#   '치다',
#   '발리다',
#   '새소리',
#   '도',
#   '가꾸다',
#   '가져오다',
#   '로',
#   '들리다',
#   '지경'],
#  ['데누보', '왜안', '하다', '모르다', '업데이트', '기다리다', '복돌', '님', '들다', '서다', '쭉', '해주다'],
#  ['초반',
#   '출시',
#   '단계',
#   '에서는',
#   '퀘스트',
#   '무기',
#   '퀘등',
#   '단',
#   '순',
#   '반복',
#   '들',
#   '이',
#   '많다',
#   '업데이트',
#   '이후',
#   '수많다',
#   '퀘',
#   '들',
#   '이',
#   '생기다',
#   '도전',
#   '과',
#   '수집',
#   '욕구',
#   '를',
#   '불다',
#   '옴'],
#  ['넘다',
#   '모',
#   '심심하다',
#   '벨트',
#   '스',
#   '크롤',
#   '겜',
#   '인',
#   '것',
#   '이야',
#   '요',
#   '뭐',
#   '가',
#   '있다',
#   '싶다',
#   '배경',
#   '에서',
#   '삽질',
#   '하다',
#   '보다',
#   '아무',
#   '것',
#   '도',
#   '없다',
#   '체력',
#   '만',
#   '줄줄',
#   '빠지다',
#   '원더보이',
#   '키드',
#   '를',
#   '사',
#   '다가',
#   '하다',
#   '낫',
#   '지',
#   '싶다'],
#  ['왜', '스피드', '가', '고속', '으로', '하다', '않다', '배', '이상', '빠르다', '느껴지다'],
#  ['개인',
#   '적',
#   '으로',
#   '게임',
#   '을',
#   '별로',
#   '좋아하다',
#   '않다',
#   '거르다',
#   '가',
#   '사람',
#   '들',
#   '이',
#   '하다',
#   '갓',
#   '겜',
#   '갓',
#   '겜',
#   '거리',
#   '길',
#   '래',
#   '세',
#   '일',
#   '때',
#   '구매',
#   '하다',
#   '해봤다',
#   '역시',
#   '난',
#   '게임',
#   '을',
#   '좋아하다',
#   '않다',
#   '사실',
#   '을',
#   '한번',
#   '더',
#   '알',
#   '게',
#   '해주다',
#   '전투',
#   '가',
#   '너무',
#   '재미없다'],
#  ['툼레이더',
#   '리부트',
#   '시리즈',
#   '를',
#   '모두',
#   '가지',
#   '고',
#   '있다',
#   '구매',
#   '하다',
#   '이번',
#   '작품',
#   '은',
#   '스토리',
#   '볼륨',
#   '도',
#   '빈약하다',
#   '최적화',
#   '는',
#   '최적화',
#   '대로',
#   '안되다',
#   '있다',
#   '이전',
#   '툼레이더',
#   '시리즈',
#   '가',
#   '모험',
#   '과',
#   '전투',
#   '두',
#   '가지',
#   '를',
#   '다',
#   '잡다',
#   '이번',
#   '작품',
#   '은',
#   '두',
#   '가지',
#   '다',
#   '놓치다',
#   '내',
#   '가',
#   '이',
#   '걸',
#   '왜',
#   '사다'],
#  ['게임',
#   '자체',
#   '는',
#   '좋다',
#   '최적화',
#   '도',
#   '존',
#   '좋다',
#   '게임',
#   '이',
#   '어렵다',
#   '정말',
#   '정말',
#   '어렵다',
#   '조작',
#   '을',
#   '베리',
#   '이지',
#   '로',
#   '해도',
#   '정말',
#   '정말',
#   '등',
#   '하다',
#   '힘들다',
#   '개인',
#   '적',
#   '으로',
#   '차탓',
#   '이라고',
#   '생각',
#   '은',
#   '한',
#   '다만',
#   '마음',
#   '어렵다',
#   '못',
#   '하다',
#   '몸',
#   '으',
#   '하하',
#   '핳',
#   '하하',
#   '하하',
#   '핳',
#   '크라이',
#   '썸',
#   '모어'],
#  ['게임',
#   '은',
#   '재밌다',
#   '문제',
#   '는',
#   '사람',
#   '이',
#   '적다',
#   '쏘다',
#   '난',
#   '후',
#   '몇',
#   '초',
#   '뒤',
#   '반동',
#   '이',
#   '나오다'],
#  ['저희',
#   '집',
#   '이',
#   '쓰레기',
#   '같다',
#   '컴',
#   '이르다',
#   '그렇다',
#   '아주',
#   '렉',
#   '이',
#   '심하다',
#   '무료',
#   '되다',
#   '가다',
#   '분들',
#   '많다',
#   '저',
#   '도',
#   '가다',
#   '보다',
#   '아주',
#   '렉',
#   '이',
#   '심하다',
#   '뇨',
#   '컴',
#   '이',
#   '아주',
#   '쓰다',
#   '렉',
#   '인',
#   '분',
#   '들',
#   '은',
#   '전',
#   '윈',
#   '비트',
#   '사용',
#   '하다',
#   '않다',
#   '추천',
#   '하다'],
#  ['퍼즐', '푸다', '중', '인데', '진짜', '재밌다'],
#  ['이',
#   '거',
#   '일단',
#   '키',
#   '면',
#   '재밌다',
#   '키기',
#   '가',
#   '싫다',
#   '요새',
#   '한글패치',
#   '때문',
#   '에',
#   '레드',
#   '훅',
#   '말',
#   '이',
#   '좀',
#   '많다',
#   '추천',
#   '줄',
#   '지',
#   '비추다',
#   '고민',
#   '하다',
#   '그래서',
#   '비추다',
#   '줌'],
#  ['오다',
#   '조작',
#   '이',
#   '매우',
#   '어렵다',
#   '사양',
#   '은',
#   '의외로',
#   '고',
#   '사양',
#   '인',
#   '것',
#   '은',
#   '물론',
#   '이고',
#   '롤러코스터',
#   '에서의',
#   '컨트롤',
#   '은',
#   '잊다',
#   '격자',
#   '가',
#   '없다',
#   '엄청나다',
#   '게임',
#   '이다',
#   '마인크래프트',
#   '처럼',
#   '격자',
#   '가',
#   '없다',
#   '매우',
#   '매우',
#   '건물',
#   '을',
#   '짓다',
#   '힘드다'],
#  ['미드',
#   '보다',
#   '게임',
#   '으로',
#   '먼저',
#   '접',
#   '한',
#   '왕좌',
#   '의',
#   '게임',
#   '처음',
#   '엔',
#   '정말',
#   '당황',
#   '하다',
#   '하다',
#   '초반',
#   '에',
#   '화살표',
#   '나오다',
#   '겁나다',
#   '누르다',
#   '안되다',
#   '마우스',
#   '도',
#   '안되다',
#   '맞다',
#   '계속',
#   '초반',
#   '에',
#   '죽다',
#   '키',
#   '보드',
#   '누르다',
#   '되다',
#   '많이',
#   '당황',
#   '하고',
#   '개',
#   '빡치다',
#   '역시',
#   '텔테일',
#   '이다',
#   '나비효과',
#   '짜다',
#   '짱'],
#  ['한국',
#   '사람인',
#   '대',
#   '핑',
#   '이',
#   '적당하다',
#   '서버',
#   '가',
#   '하나',
#   '도',
#   '없다',
#   '내',
#   '가',
#   '서버',
#   '를',
#   '만들다',
#   '없다',
#   '게임',
#   '을',
#   '재',
#   '대로',
#   '하다',
#   '없다'],
#  ['이',
#   '새끼',
#   '들',
#   '보다',
#   '살',
#   '먹다',
#   '휴대폰',
#   '에',
#   '또래',
#   '여자',
#   '번호',
#   '하나',
#   '없다',
#   '내',
#   '가',
#   '더',
#   '불상',
#   '하다',
#   '발'],
#  ['이나', '하자'],
#  ['주인공',
#   '이',
#   '급하다',
#   '대학원생',
#   '연구',
#   '에',
#   '샘플',
#   '막',
#   '제공',
#   '하다',
#   '영원하다',
#   '고통',
#   '받다',
#   '내용'],
#  ['이',
#   '거',
#   '모바일',
#   '에',
#   '있다',
#   '게임',
#   '을',
#   '그대로',
#   '옮기다',
#   '게임',
#   '이다',
#   '로',
#   '이식',
#   '하다',
#   '때',
#   '에는',
#   '인터페이스',
#   '라도',
#   '바꾸다',
#   '맞다',
#   '않다'],
#  ['이야', '멀티', '나오다'],
#  ['음', '권장', '사양', '에', '맞추다', '프레임', '이', '떨어지다'],
#  ['하다', '각종', '파일', '로', '하다', '웃기', '좋다', '게임'],
#  ['재밌다',
#   '오타쿠',
#   '들',
#   '왜',
#   '이리',
#   '불타',
#   '오름',
#   '조작',
#   '감다',
#   '이',
#   '정도',
#   '면',
#   '아니다',
#   '따리',
#   '으로',
#   '원활하다',
#   '잘',
#   '돌아가다'],
#  ['개인',
#   '적',
#   '으론',
#   '과대',
#   '평가',
#   '받다',
#   '게임',
#   '이라고',
#   '생각',
#   '하다',
#   '처음',
#   '엔',
#   '전투',
#   '시스템',
#   '이',
#   '차다',
#   '괜찮다',
#   '생각',
#   '하다',
#   '얼마',
#   '안되다',
#   '금방',
#   '지겹다',
#   '생각',
#   '을',
#   '돌이키다',
#   '보다',
#   '유저',
#   '를',
#   '사로자다',
#   '새롭다',
#   '시스템',
#   '은',
#   '부족하다',
#   '여러',
#   '게임',
#   '의',
#   '요소',
#   '들',
#   '을',
#   '자다',
#   '융합',
#   '한',
#   '게임',
#   '일',
#   '뿐',
#   '이라는',
#   '결론',
#   '을',
#   '내리다'],
#  ['어디',
#   '선',
#   '가',
#   '받다',
#   '무료',
#   '게임',
#   '생각',
#   '보다',
#   '괜찮다',
#   '돈',
#   '주다',
#   '하다',
#   '아깝다',
#   '하다'],
#  ['게임', '이', '안되다', '사다', '하다', '못', '하다'],
#  ['유사', '존윅', '게임'],
#  ['분', '정도', '하다', '멀미', '머리', '아프다', '토', '하다', '정도', '로', '심하다', '환불', '함'],
#  ['그때', '부터', '이다', '제', '가', '치다', '맞다', '다니다', '흙흙'],
#  ['처음',
#   '튜토리얼',
#   '하고',
#   '난',
#   '느낌',
#   '은',
#   '롤',
#   '근데',
#   '재미없다',
#   '습',
#   '롤',
#   '의',
#   '액션',
#   '성은',
#   '없다',
#   '롤',
#   '같다',
#   '도타',
#   '의',
#   '타',
#   '격감',
#   '은',
#   '없다',
#   '도타',
#   '같다'],
#  ['좀비', '가', '너무', '몰려오다', '그냥', '디펜스', '겜'],
#  ['배경음악', '덕분', '에', '엔딩', '까지'],
#  ['으아', '진짜', '발', '적', '화', '진짜'],
#  ['게임', '실행', '이'],
#  ['노가다',
#   '성',
#   '이',
#   '너무',
#   '심해',
#   '재미',
#   '를',
#   '떨어뜨리다',
#   '때문',
#   '에',
#   '비',
#   '추천',
#   '드리다'],
#  ['캐릭터', '가', '잘생기다', '물리다', '때', '마다', '넘다', '슬프다'],
#  ['팀', '한번', '밀리', '면', '아무', '것', '도', '못', '하다'],
#  ['뭔', '지', '잘', '모르다'],
#  ['이',
#   '평가',
#   '에서',
#   '다루다',
#   '대상',
#   '이',
#   '너무나도',
#   '무섭다',
#   '성',
#   '님',
#   '무섭다',
#   '아주',
#   '지리다',
#   '버리다',
#   '겄소'],
#  ['충각', '이', '제일', '강하다'],
#  ['솔직하다', '서버', '만', '괜찮다', '갓', '겜임'],
#  ['우와',
#   '바이브',
#   '컨트롤러',
#   '의',
#   '트리',
#   '거의',
#   '내',
#   '구성',
#   '이',
#   '걱정',
#   '되다',
#   '정도',
#   '로',
#   '정말',
#   '정신없이',
#   '플',
#   '래',
#   '이',
#   '하다',
#   '아직',
#   '캠페인',
#   '밖에',
#   '못',
#   '해봤다',
#   '정말',
#   '꼭',
#   '해보다',
#   '하다'],
#  ...]

# %%
cleaned_tokens = []

for tokens in token_list:
    temp = []
    for word in tokens:
        if word not in ko_stopwords:
            temp.append(word)
    cleaned_tokens.append(temp)

data['tokens'] = cleaned_tokens
data.head()
# Out:
#    label                          document  \
# 0      0                         노래가 너무 적음
# 1      0      돌겠네 진짜 황숙아 어크 공장 그만 돌려라 죽는다
# 2      1  막노동 체험판 막노동 하는사람인데 장비를 내가 사야돼 뭐지
# 3      1       차악차악 정말 이래서 왕국을 되찾을 수 있는거야
# 4      1   시간 때우기에 좋음 도전과제는 시간이면 다 깰 수 있어요
#
#                                          tokens
# 0                                  [노래, 너무, 적다]
# 1             [돌다, 진짜, 황숙, 어크, 공장, 그만, 돌리다, 죽다]
# 2  [막노동, 체험판, 막노동, 사람, 인데, 장비, 내, 사다, 돼다, 뭐, 지]
# 3                      [차악차악, 정말, 이래서, 왕국, 되찾다]
# 4               [때우다, 좋다, 도전, 과제, 는, 이면, 다, 깨다]

# %%
filtered_list = []

for tokens in data['tokens']:
    temp = []
    for word in tokens:
        if word not in ko_stopwords and len(word) > 1:
            temp.append(word)
    filtered_list.append(temp)

data['tokens'] = filtered_list
data.head(20)
# Out:
#     label                                           document  \
# 0       0                                          노래가 너무 적음
# 1       0                       돌겠네 진짜 황숙아 어크 공장 그만 돌려라 죽는다
# 2       1                   막노동 체험판 막노동 하는사람인데 장비를 내가 사야돼 뭐지
# 3       1                        차악차악 정말 이래서 왕국을 되찾을 수 있는거야
# 4       1                    시간 때우기에 좋음 도전과제는 시간이면 다 깰 수 있어요
# 5       1               역시 재미있네요 전작에서 할수 없었던 자유로운 덱 빌딩도 좋네요
# 6       1                                           재미있었습니다
# 7       1                                   은근 쉽지만 은근 어려운 게임
# 8       0  베 스다 이 개 끼들아 시작할 때 체스판 돌아가는거 분동안 번 봤더나 빡치네 진짜 ...
# 9       1                                  시간 분동안 스트레스 다 풀림
# 10      0                                  걍 겜임 계정을 못만들어 미친겜
# 11      0                                         관람객 호랑이 불가
# 12      1                             재미쩡 초반에 좀 힘들어여 도트라서 조아
# 13      1  포켓볼 도 몰랐는데 이걸로 배워 갑니다 심심할때 하면 좋아요 컴퓨터 상대하는거 제대...
# 14      1                                      트레이아크 사랑해요 핰핰
# 15      0                 좆망겜 하지마 무슨 처음에 키자마자 매칭이 왜 렙하고 매칭되냐
# 16      1  뭐랄까 다크소울하는느낌이에요 죽으면 돈 다날라가는 방식 렙업하면서 무한 반복인거같은...
# 17      1  원하는거 보실려면 홈페이지 가셔서 패치를 사셔야 합니다 패치가 만원이라 사실상 만원...
# 18      0  안해 썩을 까진 그냥 대충 슥슥해도 되더니 에서 판때기를 직접 사용하는데 판을 밟는...
# 19      0                                                 우웩
#
#                                                tokens
# 0                                        [노래, 너무, 적다]
# 1                   [돌다, 진짜, 황숙, 어크, 공장, 그만, 돌리다, 죽다]
# 2                 [막노동, 체험판, 막노동, 사람, 인데, 장비, 사다, 돼다]
# 3                            [차악차악, 정말, 이래서, 왕국, 되찾다]
# 4                           [때우다, 좋다, 도전, 과제, 이면, 깨다]
# 5                        [역시, 재미있다, 전작, 자유롭다, 빌딩, 좋다]
# 6                                              [재미있다]
# 7                               [은근, 쉬다, 은근, 어렵다, 게임]
# 8   [시작, 체스판, 돌아가다, 분동, 보다, 빡치다, 진짜, 무한, 로딩, 버그, 치...
# 9                                      [분동, 스트레스, 풀림]
# 10                                      [겜임, 계정, 만들다]
# 11                                     [관람객, 호랑이, 불가]
# 12                          [재미, 초반, 힘들다, 도트, 라서, 조아]
# 13  [포켓볼, 모르다, 배우다, 가다, 심심하다, 좋다, 컴퓨터, 상대, 제대로, 이기...
# 14                                    [트레이아크, 사랑, 핰핰]
# 15                                   [좆망, 처음, 매칭, 매칭]
# 16  [뭐라다, 다크, 소울, 느낌, 이에요, 죽다, 다날, 라가, 방식, 렙업, 무한,...
# 17  [원하다, 보다, 홈페이지, 갈다, 패치, 사다, 패치, 만원, 이라, 사실, 만원...
# 18  [안해, 썩을, 까진, 그냥, 대충, 판때, 기르다, 직접, 사용, 밟다, 순간, ...
# 19                                               [우웩]
